# %% [markdown]
# # Import the packages and check connection to bucket

# %%
from google.cloud import storage
import pandas as pd ## for dataset and eda
import numpy as np ## for eda
from datetime import datetime
from tqdm import tqdm

# %%
bucket_name = "firstprojectdl"

storage_client = storage.Client()
bucket = storage_client.get_bucket(bucket_name)

print(bucket)
print('Great, we now have access to our first bucket on google cloud storage where we put our data')
# Out:
# <Bucket: firstprojectdl>
# Great, we now have access to our first bucket on google cloud storage where we put our data

# %%
from google.cloud import storage
import pandas as pd

bucket_name = "firstprojectdl"

storage_client = storage.Client()
bucket = storage_client.get_bucket(bucket_name)

# When you have your files in a subfolder of the bucket.
my_prefix = "data/movieLens/movieLens20M/" # the name of the subfolder
blobs = bucket.list_blobs(prefix = my_prefix, delimiter = '/')

dfDict = {}
dateparse = lambda x: datetime.utcfromtimestamp(int(x)).strftime('%Y-%m-%d %H:%M:%S')

for blob in blobs:
    if(blob.name != my_prefix): # ignoring the subfolder itself 
        file_name = blob.name.replace(my_prefix, "")
        blob.download_to_filename(file_name) # download the file to the machine
        print(file_name)
        if file_name =='ratings20M.dat':
            df = pd.read_csv(file_name, sep=',', 
                            names=['user_id', 'movie_id', 'rating', 'timestamp'],
                            skiprows = 1, 
                            parse_dates=['timestamp'], 
                            date_parser=dateparse) # load the rating data
# Out:
# ratings20M.dat

# %% [markdown]
# ## Memory Error with 20 million dataset then we will only read the file with first 2.5 million rows

# %%
df.head()
# Out:
#    user_id  movie_id  rating           timestamp
# 0        1         2     3.5 2005-04-02 23:53:47
# 1        1        29     3.5 2005-04-02 23:31:16
# 2        1        32     3.5 2005-04-02 23:33:39
# 3        1        47     3.5 2005-04-02 23:32:07
# 4        1        50     3.5 2005-04-02 23:29:40

# %%
df = df.loc[df['movie_id'].isin(range(15000)) & df['user_id'].isin(range(15000)), :]

# %%
df.head()
# Out:
#    user_id  movie_id  rating           timestamp
# 0        1         2     3.5 2005-04-02 23:53:47
# 1        1        29     3.5 2005-04-02 23:31:16
# 2        1        32     3.5 2005-04-02 23:33:39
# 3        1        47     3.5 2005-04-02 23:32:07
# 4        1        50     3.5 2005-04-02 23:29:40

# %%
listMovies = np.sort(df.movie_id.unique())
ind = 0
for movies in tqdm(listMovies):
    df.loc[df['movie_id'] == movies, 'movie_id'] = ind
    ind += 1
# Out:
# 100%|██████████| 8337/8337 [21:09<00:00,  6.57it/s]

# %%
listMovies = df.movie_id.unique()
len(listMovies)
# Out:
# 8337

# %%
listMovies = df.movie_id.unique()
len(listMovies)
# Out:
# 8337

# %%
listMovies.sort()

# %%
df.to_csv('ratings2.5M.dat')

# %%
df.head()
# Out:
#    user_id  movie_id  rating           timestamp
# 0        1         1     3.5 2005-04-02 23:53:47
# 1        1        28     3.5 2005-04-02 23:31:16
# 2        1        31     3.5 2005-04-02 23:33:39
# 3        1        46     3.5 2005-04-02 23:32:07
# 4        1        49     3.5 2005-04-02 23:29:40

# %%
num_users = df.user_id.unique().shape[0]
print(f'The datasets presents {num_users} users')
# Out:
# The datasets presents 138485 users

# %%
num_ratings = df.rating.shape[0]
print(f'The datasets presents {num_ratings} distinct ratings')
# Out:
# The datasets presents 17647768 distinct ratings

# %%
num_items = df.movie_id.unique().shape[0]
print(f'The datasets presents {num_items} items')
# Out:
# The datasets presents 8337 items

# %%
df.movie_id.unique()
# Out:
# array([   1,   28,   31, ..., 8024, 7500, 6829])

# %%
with open('ratings2.5M.dat') as infile:
  with open('ratings2.5MNew.dat', 'w') as outfile:
    for line in infile:
      fields = line.split(',')
      outfile.write('::'.join(fields))

# %%
fp = open("ratings2.5MNew.dat")
lines = fp.readlines()

# %%
lines[0]
# Out:
# '::user_id::movie_id::rating::timestamp\n'

# %%
import numpy as np

# %%
# Comet ML for experiment logging
from comet_ml import Experiment

# %%
# Import packages
import tensorflow as tf
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# Set random seed
tf.random.set_random_seed(1994)
np.random.seed(1994)

# %%
def read_rating(num_users, num_items, num_total_ratings, a, b, train_ratio):
    """
    Function to read in the ratings data
    :param path: path to ratings data
    :param num_users: number of users
    :param num_items: number of items
    :param num_total_ratings: number of total ratings
    :param a: positive rating (1)
    :param b: negative rating (0)
    :param train_ratio: ratio that splits train and test sets
    """
    fp = open("ratings2.5MNew.dat")

    user_train_set = set()
    user_test_set = set()
    item_train_set = set()
    item_test_set = set()

    R = np.zeros((num_users, num_items))
    mask_R = np.zeros((num_users, num_items))
    C = np.ones((num_users, num_items)) * b

    train_R = np.zeros((num_users, num_items))
    test_R = np.zeros((num_users, num_items))

    train_mask_R = np.zeros((num_users, num_items))
    test_mask_R = np.zeros((num_users, num_items))

    random_perm_idx = np.random.permutation(num_total_ratings)
    train_idx = random_perm_idx[0:int(num_total_ratings * train_ratio)]
    test_idx = random_perm_idx[int(num_total_ratings * train_ratio):]

    num_train_ratings = len(train_idx)
    num_test_ratings = len(test_idx)

    lines = fp.readlines()
    for line in lines[1:]:
        _, user, item, rating, _ = line.split("::")
        user_idx = int(user) - 1
        item_idx = int(item) - 1
        R[user_idx, item_idx] = float(rating)
        mask_R[user_idx, item_idx] = 1
        C[user_idx, item_idx] = a

    # Training set
    for itr in train_idx:
        line = lines[itr]
        _, user, item, rating, _ = line.split("::")
        if (user == 'user_id') | (item == 'movie_id') | (rating == 'rating'):
            continue
        user_idx = int(user) - 1
        item_idx = int(item) - 1
        train_R[user_idx, item_idx] = float(rating)
        train_mask_R[user_idx, item_idx] = 1

        user_train_set.add(user_idx)
        item_train_set.add(item_idx)

    # Test set
    for itr in test_idx:
        line = lines[itr]
        _, user, item, rating, _ = line.split("::")
        if (user == 'user_id') | (item == 'movie_id') | (rating == 'rating'):
            continue
        user_idx = int(user) - 1
        item_idx = int(item) - 1
        test_R[user_idx, item_idx] = float(rating)
        test_mask_R[user_idx, item_idx] = 1

        user_test_set.add(user_idx)
        item_test_set.add(item_idx)

    return R, mask_R, C, train_R, train_mask_R, test_R, test_mask_R, num_train_ratings, num_test_ratings, \
           user_train_set, item_train_set, user_test_set, item_test_set

# %%
data_name = 'ml-2.5M'
num_users = 138485
num_items = 8337 
num_total_ratings = 17647768
# Data is split into random 75% - 25% train-test sets
train_ratio = 0.75

# %%
R, mask_R, C, train_R, train_mask_R, test_R, test_mask_R, num_train_ratings, num_test_ratings, \
user_train_set, item_train_set, user_test_set, item_test_set = read_rating(num_users, num_items, num_total_ratings, 1, 0, train_ratio)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-79-c56baec7e523> in <module>
#       1 R, mask_R, C, train_R, train_mask_R, test_R, test_mask_R, num_train_ratings, num_test_ratings, \
# ----> 2 user_train_set, item_train_set, user_test_set, item_test_set = read_rating(num_users, num_items, num_total_ratings, 1, 0, train_ratio)
#
# <ipython-input-77-2a962007a8ff> in read_rating(num_users, num_items, num_total_ratings, a, b, train_ratio)
#      21     C = np.ones((num_users, num_items)) * b
#      22
# ---> 23     train_R = np.zeros((num_users, num_items))
#      24     test_R = np.zeros((num_users, num_items))
#      25
#
# MemoryError: Unable to allocate 8.60 GiB for an array with shape (138485, 8337) and data type float64

# %%
# Get hyper-parameters
hyper_params = {
    "hidden_neuron": 500,
    "lambda_value": 1,
    "epochs": 500,
    "batch_size": 512,
    "optimizer": "Adam",
    "learning_rate": 0.001,
    "random_seed": 1994
}

# %%
# Import packages
import tensorflow as tf
import time
import numpy as np
import os
import math

# %%
class AutoRec:
    """
    Function to define the AutoRec model class
    """
    def __init__(self, sess, args,
                 num_users, num_items,
                 R, mask_R, C, train_R, train_mask_R, test_R, test_mask_R, num_train_ratings, num_test_ratings,
                 user_train_set, item_train_set, user_test_set, item_test_set,
                 result_path):

        self.sess = sess
        self.args = args

        self.num_users = num_users
        self.num_items = num_items

        self.R = R
        self.mask_R = mask_R
        self.C = C
        self.train_R = train_R
        self.train_mask_R = train_mask_R
        self.test_R = test_R
        self.test_mask_R = test_mask_R
        self.num_train_ratings = num_train_ratings
        self.num_test_ratings = num_test_ratings

        self.user_train_set = user_train_set
        self.item_train_set = item_train_set
        self.user_test_set = user_test_set
        self.item_test_set = item_test_set

        self.hidden_neuron = args['hidden_neuron']
        self.train_epoch = args['train_epoch']
        self.batch_size = args['batch_size']
        self.num_batch = int(math.ceil(self.num_users / float(self.batch_size)))

        self.base_lr = args['base_lr']
        self.optimizer_method = args['optimizer_method']
        self.display_step = args['display_step']
        self.random_seed = args['random_seed']

        self.global_step = tf.Variable(0, trainable=False)
        self.decay_epoch_step = args['decay_epoch_step']
        self.decay_step = self.decay_epoch_step * self.num_batch
        self.lr = tf.compat.v1.train.exponential_decay(self.base_lr, self.global_step,
                                                       self.decay_step, 0.96, staircase=True)
        self.lambda_value = args['lambda_value']

        self.train_cost_list = []
        self.test_cost_list = []
        self.test_rmse_list = []

        self.result_path = result_path
        self.grad_clip = args['grad_clip']

    def run(self, experiment):
        """
        Function to run AutoRec
        :param experiment: CometML Experiment function
        """
        # Build AutoRec
        self.prepare_model()
        init = tf.compat.v1.global_variables_initializer()
        self.sess.run(init)

        # Train and evaluate AutoRec for all epochs
        for epoch_itr in range(self.train_epoch):
            experiment.set_step(epoch_itr)
            self.train_model(epoch_itr,experiment)
            self.test_model(epoch_itr, experiment)

        # Log results
        self.make_records()

    def prepare_model(self):
        """
        Function to build AutoRec
        """
        self.input_R = tf.compat.v1.placeholder(dtype=tf.float32,
                                                shape=[None, self.num_items],
                                                name="input_R")
        self.input_mask_R = tf.compat.v1.placeholder(dtype=tf.float32,
                                                     shape=[None, self.num_items],
                                                     name="input_mask_R")

        V = tf.compat.v1.get_variable(name="V", initializer=tf.compat.v1.truncated_normal(
            shape=[self.num_items, self.hidden_neuron],
            mean=0, stddev=0.03), dtype=tf.float32)
        W = tf.compat.v1.get_variable(name="W", initializer=tf.compat.v1.truncated_normal(
            shape=[self.hidden_neuron, self.num_items],
            mean=0, stddev=0.03), dtype=tf.float32)
        mu = tf.compat.v1.get_variable(name="mu", initializer=tf.zeros(shape=self.hidden_neuron), dtype=tf.float32)
        b = tf.compat.v1.get_variable(name="b", initializer=tf.zeros(shape=self.num_items), dtype=tf.float32)

        pre_Encoder = tf.matmul(self.input_R, V) + mu
        self.Encoder = tf.nn.sigmoid(pre_Encoder)
        pre_Decoder = tf.matmul(self.Encoder, W) + b
        self.Decoder = tf.identity(pre_Decoder)

        pre_rec_cost = tf.multiply((self.input_R - self.Decoder), self.input_mask_R)
        rec_cost = tf.square(self.l2_norm(pre_rec_cost))
        pre_reg_cost = tf.square(self.l2_norm(W)) + tf.square(self.l2_norm(V))
        reg_cost = self.lambda_value * 0.5 * pre_reg_cost

        self.cost = rec_cost + reg_cost

        if self.optimizer_method == "Adam":
            optimizer = tf.compat.v1.train.AdamOptimizer(self.lr)
        elif self.optimizer_method == "RMSProp":
            optimizer = tf.compat.v1.train.RMSPropOptimizer(self.lr)
        else:
            raise ValueError("Optimizer Key ERROR")

        if self.grad_clip:
            gvs = optimizer.compute_gradients(self.cost)
            capped_gvs = [(tf.clip_by_value(grad, -5., 5.), var) for grad, var in gvs]
            self.optimizer = optimizer.apply_gradients(capped_gvs, global_step=self.global_step)
        else:
            self.optimizer = optimizer.minimize(self.cost, global_step=self.global_step)

    def train_model(self, itr, experiment):
        """
        Function to train AutoRec
        :param itr: Current iteration
        :param experiment: CometML experiment
        """
        start_time = time.time()
        random_perm_doc_idx = np.random.permutation(self.num_users)

        batch_cost = 0
        for i in range(self.num_batch):
            if i == self.num_batch - 1:
                batch_set_idx = random_perm_doc_idx[i * self.batch_size:]
            elif i < self.num_batch - 1:
                batch_set_idx = random_perm_doc_idx[i * self.batch_size: (i + 1) * self.batch_size]

            _, Cost = self.sess.run(
                [self.optimizer, self.cost],
                feed_dict={self.input_R: self.train_R[batch_set_idx, :],
                           self.input_mask_R: self.train_mask_R[batch_set_idx, :]})

            batch_cost = batch_cost + Cost
        self.train_cost_list.append(batch_cost)

        if (itr + 1) % self.display_step == 0:

            print("Training //", "Epoch %d //" % (itr), " Total cost = {:.2f}".format(batch_cost),
                  "Elapsed time : %d sec" % (time.time() - start_time))

        experiment.log_metric("loss", batch_cost, step=itr)

    def test_model(self, itr, experiment):
        """
        Function to evaluate AutoRec
        :param itr: Current iteration
        :param experiment: CometML experiment
        """
        start_time = time.time()
        Cost, Decoder = self.sess.run(
            [self.cost, self.Decoder],
            feed_dict={self.input_R: self.test_R,
                       self.input_mask_R: self.test_mask_R})

        self.test_cost_list.append(Cost)

        if (itr + 1) % self.display_step == 0:
            Estimated_R = Decoder.clip(min=1, max=5)
            unseen_user_test_list = list(self.user_test_set - self.user_train_set)
            unseen_item_test_list = list(self.item_test_set - self.item_train_set)

            for user in unseen_user_test_list:
                for item in unseen_item_test_list:
                    if self.test_mask_R[user, item] == 1:  # exist in test set
                        Estimated_R[user, item] = 3

            pre_numerator = np.multiply((Estimated_R - self.test_R), self.test_mask_R)
            numerator = np.sum(np.square(pre_numerator))
            denominator = self.num_test_ratings
            RMSE = np.sqrt(numerator / float(denominator))

            self.test_rmse_list.append(RMSE)

            print("Testing //", "Epoch %d //" % (itr), " Total cost = {:.2f}".format(Cost),
                  " RMSE = {:.5f}".format(RMSE),
                  "Elapsed time : %d sec" % (time.time() - start_time))
            print("=" * 100)

        experiment.log_metric("RMSE", RMSE, step=itr)

    def make_records(self):
        """
        Function to log results
        """
        if not os.path.exists(self.result_path):
            os.makedirs(self.result_path)

        basic_info = self.result_path + "basic_info.txt"
        train_record = self.result_path + "train_record.txt"
        test_record = self.result_path + "test_record.txt"

        with open(train_record, 'w') as f:
            f.write(str("Cost:"))
            f.write('\t')
            for itr in range(len(self.train_cost_list)):
                f.write(str(self.train_cost_list[itr]))
                f.write('\t')
            f.write('\n')

        with open(test_record, 'w') as g:
            g.write(str("Cost:"))
            g.write('\t')
            for itr in range(len(self.test_cost_list)):
                g.write(str(self.test_cost_list[itr]))
                g.write('\t')
            g.write('\n')

            g.write(str("RMSE:"))
            for itr in range(len(self.test_rmse_list)):
                g.write(str(self.test_rmse_list[itr]))
                g.write('\t')
            g.write('\n')

        #with open(basic_info, 'w') as h:
        #    h.write(str(self.args))

    def l2_norm(self, tensor):
        """
        Function to apply L2 normalization
        :param tensor: TensorFlow tensor
        """
        return tf.sqrt(tf.reduce_sum(tf.square(tensor)))

# %%
# Initialize TensorFlow Config
config = tf.compat.v1.ConfigProto()

# %%
experiment = Experiment(api_key="vV3GGUE8tetqNJuD2kGxVi1M9", project_name="autoencoders-movielens100k")
experiment.log_parameters(hyper_params)
# Out:
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/benichou/autoencoders-movielens100k/f54972cb05fe4c6080b5df21f97c310d

# %%
args = {'hidden_neuron': 500, 'lambda_value':1, 'train_epoch': 500, 'batch_size': 512, 'optimizer_method': 'Adam', 'grad_clip': False, 'base_lr': 1e-3, 'decay_epoch_step': 50, 'random_seed':1994, 'display_step':1}

# %%
result_path = 'results/'

# %%
with tf.compat.v1.Session(config=config) as sess:
    # Define the AutoRec class from `AutoRec.py`
    AutoRec = AutoRec(sess, args,
                      num_users, num_items,
                      R, mask_R, C, train_R, train_mask_R, test_R, test_mask_R, num_train_ratings, num_test_ratings,
                      user_train_set, item_train_set, user_test_set, item_test_set,
                      result_path)
    # Run the AutoRec model
    AutoRec.run(experiment)
# Out:
# COMET ERROR: Failed to extract parameters from Optimizer.init()
# Training // Epoch 0 //  Total cost = 976308.34 Elapsed time : 0 sec
# Testing // Epoch 0 //  Total cost = 258749.88  RMSE = 2.75741 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1 //  Total cost = 695662.16 Elapsed time : 0 sec
# Testing // Epoch 1 //  Total cost = 179643.67  RMSE = 2.59346 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 2 //  Total cost = 428384.17 Elapsed time : 0 sec
# Testing // Epoch 2 //  Total cost = 110844.05  RMSE = 2.09561 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 3 //  Total cost = 223343.49 Elapsed time : 0 sec
# Testing // Epoch 3 //  Total cost = 62419.16  RMSE = 1.57035 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 4 //  Total cost = 121912.77 Elapsed time : 0 sec
# Testing // Epoch 4 //  Total cost = 39626.20  RMSE = 1.24654 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 5 //  Total cost = 113911.14 Elapsed time : 0 sec
# Testing // Epoch 5 //  Total cost = 35623.78  RMSE = 1.17936 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 6 //  Total cost = 144447.08 Elapsed time : 0 sec
# Testing // Epoch 6 //  Total cost = 37495.52  RMSE = 1.20582 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 7 //  Total cost = 161125.89 Elapsed time : 0 sec
# Testing // Epoch 7 //  Total cost = 37728.92  RMSE = 1.20510 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 8 //  Total cost = 151385.23 Elapsed time : 0 sec
# Testing // Epoch 8 //  Total cost = 35842.86  RMSE = 1.17485 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 9 //  Total cost = 128225.35 Elapsed time : 0 sec
# Testing // Epoch 9 //  Total cost = 34078.30  RMSE = 1.14907 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 10 //  Total cost = 105938.54 Elapsed time : 0 sec
# Testing // Epoch 10 //  Total cost = 34117.99  RMSE = 1.15263 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 11 //  Total cost = 91878.18 Elapsed time : 0 sec
# Testing // Epoch 11 //  Total cost = 35939.30  RMSE = 1.18495 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 12 //  Total cost = 86937.77 Elapsed time : 0 sec
# Testing // Epoch 12 //  Total cost = 38384.93  RMSE = 1.22596 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 13 //  Total cost = 87339.85 Elapsed time : 0 sec
# Testing // Epoch 13 //  Total cost = 40243.78  RMSE = 1.25602 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 14 //  Total cost = 88447.18 Elapsed time : 0 sec
# Testing // Epoch 14 //  Total cost = 40784.09  RMSE = 1.26460 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 15 //  Total cost = 87991.24 Elapsed time : 0 sec
# Testing // Epoch 15 //  Total cost = 40035.28  RMSE = 1.25267 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 16 //  Total cost = 85877.03 Elapsed time : 0 sec
# Testing // Epoch 16 //  Total cost = 38306.70  RMSE = 1.22471 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 17 //  Total cost = 82712.30 Elapsed time : 0 sec
# Testing // Epoch 17 //  Total cost = 36258.90  RMSE = 1.19075 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 18 //  Total cost = 80056.68 Elapsed time : 0 sec
# Testing // Epoch 18 //  Total cost = 34372.45  RMSE = 1.15856 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 19 //  Total cost = 78271.90 Elapsed time : 0 sec
# Testing // Epoch 19 //  Total cost = 32923.54  RMSE = 1.13321 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 20 //  Total cost = 77528.44 Elapsed time : 0 sec
# Testing // Epoch 20 //  Total cost = 31918.24  RMSE = 1.11529 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 21 //  Total cost = 77134.94 Elapsed time : 0 sec
# Testing // Epoch 21 //  Total cost = 31301.22  RMSE = 1.10416 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 22 //  Total cost = 76637.83 Elapsed time : 0 sec
# Testing // Epoch 22 //  Total cost = 31017.81  RMSE = 1.09904 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 23 //  Total cost = 75785.67 Elapsed time : 0 sec
# Testing // Epoch 23 //  Total cost = 30983.82  RMSE = 1.09845 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 24 //  Total cost = 74983.30 Elapsed time : 0 sec
# Testing // Epoch 24 //  Total cost = 31188.08  RMSE = 1.10222 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 25 //  Total cost = 74116.24 Elapsed time : 0 sec
# Testing // Epoch 25 //  Total cost = 31502.63  RMSE = 1.10797 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 26 //  Total cost = 73529.78 Elapsed time : 0 sec
# Testing // Epoch 26 //  Total cost = 31826.17  RMSE = 1.11383 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 27 //  Total cost = 73156.97 Elapsed time : 0 sec
# Testing // Epoch 27 //  Total cost = 32045.12  RMSE = 1.11777 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 28 //  Total cost = 72791.82 Elapsed time : 0 sec
# Testing // Epoch 28 //  Total cost = 32087.28  RMSE = 1.11853 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 29 //  Total cost = 72399.35 Elapsed time : 0 sec
# Testing // Epoch 29 //  Total cost = 31962.88  RMSE = 1.11629 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 30 //  Total cost = 71905.17 Elapsed time : 0 sec
# Testing // Epoch 30 //  Total cost = 31695.56  RMSE = 1.11146 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 31 //  Total cost = 71469.90 Elapsed time : 0 sec
# Testing // Epoch 31 //  Total cost = 31376.53  RMSE = 1.10567 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 32 //  Total cost = 71015.78 Elapsed time : 0 sec
# Testing // Epoch 32 //  Total cost = 31072.88  RMSE = 1.10014 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 33 //  Total cost = 70659.51 Elapsed time : 0 sec
# Testing // Epoch 33 //  Total cost = 30827.15  RMSE = 1.09564 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 34 //  Total cost = 70301.38 Elapsed time : 0 sec
# Testing // Epoch 34 //  Total cost = 30659.50  RMSE = 1.09256 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 35 //  Total cost = 69958.73 Elapsed time : 0 sec
# Testing // Epoch 35 //  Total cost = 30561.70  RMSE = 1.09076 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 36 //  Total cost = 69582.15 Elapsed time : 0 sec
# Testing // Epoch 36 //  Total cost = 30505.17  RMSE = 1.08972 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 37 //  Total cost = 69228.96 Elapsed time : 0 sec
# Testing // Epoch 37 //  Total cost = 30493.56  RMSE = 1.08950 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 38 //  Total cost = 68861.16 Elapsed time : 0 sec
# Testing // Epoch 38 //  Total cost = 30482.89  RMSE = 1.08929 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 39 //  Total cost = 68513.07 Elapsed time : 0 sec
# Testing // Epoch 39 //  Total cost = 30461.45  RMSE = 1.08887 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 40 //  Total cost = 68164.62 Elapsed time : 0 sec
# Testing // Epoch 40 //  Total cost = 30442.71  RMSE = 1.08850 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 41 //  Total cost = 67806.79 Elapsed time : 0 sec
# Testing // Epoch 41 //  Total cost = 30400.27  RMSE = 1.08769 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 42 //  Total cost = 67463.75 Elapsed time : 0 sec
# Testing // Epoch 42 //  Total cost = 30350.23  RMSE = 1.08674 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 43 //  Total cost = 67104.73 Elapsed time : 0 sec
# Testing // Epoch 43 //  Total cost = 30295.97  RMSE = 1.08571 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 44 //  Total cost = 66764.89 Elapsed time : 0 sec
# Testing // Epoch 44 //  Total cost = 30209.34  RMSE = 1.08409 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 45 //  Total cost = 66404.90 Elapsed time : 0 sec
# Testing // Epoch 45 //  Total cost = 30150.92  RMSE = 1.08299 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 46 //  Total cost = 66044.44 Elapsed time : 0 sec
# Testing // Epoch 46 //  Total cost = 30106.00  RMSE = 1.08214 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 47 //  Total cost = 65687.06 Elapsed time : 0 sec
# Testing // Epoch 47 //  Total cost = 30059.58  RMSE = 1.08125 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 48 //  Total cost = 65328.21 Elapsed time : 0 sec
# Testing // Epoch 48 //  Total cost = 30022.05  RMSE = 1.08053 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 49 //  Total cost = 64979.53 Elapsed time : 0 sec
# Testing // Epoch 49 //  Total cost = 29989.52  RMSE = 1.07990 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 50 //  Total cost = 64624.44 Elapsed time : 0 sec
# Testing // Epoch 50 //  Total cost = 29968.90  RMSE = 1.07949 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 51 //  Total cost = 64256.17 Elapsed time : 0 sec
# Testing // Epoch 51 //  Total cost = 29903.38  RMSE = 1.07824 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 52 //  Total cost = 63926.37 Elapsed time : 0 sec
# Testing // Epoch 52 //  Total cost = 29869.59  RMSE = 1.07758 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 53 //  Total cost = 63573.17 Elapsed time : 0 sec
# Testing // Epoch 53 //  Total cost = 29824.65  RMSE = 1.07671 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 54 //  Total cost = 63229.92 Elapsed time : 0 sec
# Testing // Epoch 54 //  Total cost = 29784.78  RMSE = 1.07594 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 55 //  Total cost = 62881.52 Elapsed time : 0 sec
# Testing // Epoch 55 //  Total cost = 29751.71  RMSE = 1.07529 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 56 //  Total cost = 62535.60 Elapsed time : 0 sec
# Testing // Epoch 56 //  Total cost = 29733.86  RMSE = 1.07492 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 57 //  Total cost = 62170.32 Elapsed time : 0 sec
# Testing // Epoch 57 //  Total cost = 29708.08  RMSE = 1.07441 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 58 //  Total cost = 61823.26 Elapsed time : 0 sec
# Testing // Epoch 58 //  Total cost = 29669.06  RMSE = 1.07364 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 59 //  Total cost = 61466.56 Elapsed time : 0 sec
# Testing // Epoch 59 //  Total cost = 29647.78  RMSE = 1.07321 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 60 //  Total cost = 61116.84 Elapsed time : 0 sec
# Testing // Epoch 60 //  Total cost = 29611.31  RMSE = 1.07249 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 61 //  Total cost = 60763.89 Elapsed time : 0 sec
# Testing // Epoch 61 //  Total cost = 29595.04  RMSE = 1.07215 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 62 //  Total cost = 60414.26 Elapsed time : 0 sec
# Testing // Epoch 62 //  Total cost = 29592.45  RMSE = 1.07206 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 63 //  Total cost = 60062.12 Elapsed time : 0 sec
# Testing // Epoch 63 //  Total cost = 29569.98  RMSE = 1.07160 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 64 //  Total cost = 59692.75 Elapsed time : 0 sec
# Testing // Epoch 64 //  Total cost = 29525.54  RMSE = 1.07072 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 65 //  Total cost = 59350.67 Elapsed time : 0 sec
# Testing // Epoch 65 //  Total cost = 29502.18  RMSE = 1.07024 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 66 //  Total cost = 58998.72 Elapsed time : 0 sec
# Testing // Epoch 66 //  Total cost = 29483.55  RMSE = 1.06985 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 67 //  Total cost = 58648.10 Elapsed time : 0 sec
# Testing // Epoch 67 //  Total cost = 29474.07  RMSE = 1.06964 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 68 //  Total cost = 58297.07 Elapsed time : 0 sec
# Testing // Epoch 68 //  Total cost = 29464.50  RMSE = 1.06942 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 69 //  Total cost = 57938.29 Elapsed time : 0 sec
# Testing // Epoch 69 //  Total cost = 29442.82  RMSE = 1.06896 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 70 //  Total cost = 57581.09 Elapsed time : 0 sec
# Testing // Epoch 70 //  Total cost = 29436.05  RMSE = 1.06879 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 71 //  Total cost = 57233.04 Elapsed time : 0 sec
# Testing // Epoch 71 //  Total cost = 29422.32  RMSE = 1.06848 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 72 //  Total cost = 56891.72 Elapsed time : 0 sec
# Testing // Epoch 72 //  Total cost = 29407.29  RMSE = 1.06815 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 73 //  Total cost = 56537.55 Elapsed time : 0 sec
# Testing // Epoch 73 //  Total cost = 29365.31  RMSE = 1.06731 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 74 //  Total cost = 56187.44 Elapsed time : 0 sec
# Testing // Epoch 74 //  Total cost = 29362.20  RMSE = 1.06720 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 75 //  Total cost = 55840.31 Elapsed time : 0 sec
# Testing // Epoch 75 //  Total cost = 29348.02  RMSE = 1.06689 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 76 //  Total cost = 55493.17 Elapsed time : 0 sec
# Testing // Epoch 76 //  Total cost = 29332.58  RMSE = 1.06655 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 77 //  Total cost = 55149.02 Elapsed time : 0 sec
# Testing // Epoch 77 //  Total cost = 29330.62  RMSE = 1.06646 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 78 //  Total cost = 54793.50 Elapsed time : 0 sec
# Testing // Epoch 78 //  Total cost = 29320.45  RMSE = 1.06621 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 79 //  Total cost = 54440.38 Elapsed time : 0 sec
# Testing // Epoch 79 //  Total cost = 29297.21  RMSE = 1.06572 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 80 //  Total cost = 54103.56 Elapsed time : 0 sec
# Testing // Epoch 80 //  Total cost = 29298.84  RMSE = 1.06570 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 81 //  Total cost = 53750.02 Elapsed time : 0 sec
# Testing // Epoch 81 //  Total cost = 29278.12  RMSE = 1.06524 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 82 //  Total cost = 53407.79 Elapsed time : 0 sec
# Testing // Epoch 82 //  Total cost = 29264.52  RMSE = 1.06493 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 83 //  Total cost = 53070.05 Elapsed time : 0 sec
# Testing // Epoch 83 //  Total cost = 29254.46  RMSE = 1.06468 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 84 //  Total cost = 52739.10 Elapsed time : 0 sec
# Testing // Epoch 84 //  Total cost = 29251.98  RMSE = 1.06458 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 85 //  Total cost = 52396.26 Elapsed time : 0 sec
# Testing // Epoch 85 //  Total cost = 29253.47  RMSE = 1.06455 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 86 //  Total cost = 52055.54 Elapsed time : 0 sec
# Testing // Epoch 86 //  Total cost = 29249.79  RMSE = 1.06442 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 87 //  Total cost = 51716.21 Elapsed time : 0 sec
# Testing // Epoch 87 //  Total cost = 29240.17  RMSE = 1.06418 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 88 //  Total cost = 51382.92 Elapsed time : 0 sec
# Testing // Epoch 88 //  Total cost = 29236.96  RMSE = 1.06406 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 89 //  Total cost = 51043.04 Elapsed time : 0 sec
# Testing // Epoch 89 //  Total cost = 29222.43  RMSE = 1.06373 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 90 //  Total cost = 50706.61 Elapsed time : 0 sec
# Testing // Epoch 90 //  Total cost = 29211.27  RMSE = 1.06345 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 91 //  Total cost = 50375.66 Elapsed time : 0 sec
# Testing // Epoch 91 //  Total cost = 29198.11  RMSE = 1.06314 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 92 //  Total cost = 50059.08 Elapsed time : 0 sec
# Testing // Epoch 92 //  Total cost = 29197.41  RMSE = 1.06307 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 93 //  Total cost = 49727.13 Elapsed time : 0 sec
# Testing // Epoch 93 //  Total cost = 29201.54  RMSE = 1.06309 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 94 //  Total cost = 49404.00 Elapsed time : 0 sec
# Testing // Epoch 94 //  Total cost = 29173.52  RMSE = 1.06250 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 95 //  Total cost = 49063.36 Elapsed time : 0 sec
# Testing // Epoch 95 //  Total cost = 29165.96  RMSE = 1.06229 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 96 //  Total cost = 48743.19 Elapsed time : 0 sec
# Testing // Epoch 96 //  Total cost = 29155.43  RMSE = 1.06202 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 97 //  Total cost = 48414.36 Elapsed time : 0 sec
# Testing // Epoch 97 //  Total cost = 29151.60  RMSE = 1.06189 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 98 //  Total cost = 48093.71 Elapsed time : 0 sec
# Testing // Epoch 98 //  Total cost = 29147.69  RMSE = 1.06175 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 99 //  Total cost = 47769.22 Elapsed time : 0 sec
# Testing // Epoch 99 //  Total cost = 29140.70  RMSE = 1.06155 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 100 //  Total cost = 47447.76 Elapsed time : 0 sec
# Testing // Epoch 100 //  Total cost = 29129.90  RMSE = 1.06129 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 101 //  Total cost = 47140.29 Elapsed time : 0 sec
# Testing // Epoch 101 //  Total cost = 29121.61  RMSE = 1.06107 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 102 //  Total cost = 46836.71 Elapsed time : 0 sec
# Testing // Epoch 102 //  Total cost = 29106.18  RMSE = 1.06072 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 103 //  Total cost = 46516.89 Elapsed time : 0 sec
# Testing // Epoch 103 //  Total cost = 29091.89  RMSE = 1.06039 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 104 //  Total cost = 46212.85 Elapsed time : 0 sec
# Testing // Epoch 104 //  Total cost = 29092.43  RMSE = 1.06033 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 105 //  Total cost = 45912.04 Elapsed time : 0 sec
# Testing // Epoch 105 //  Total cost = 29093.85  RMSE = 1.06029 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 106 //  Total cost = 45604.67 Elapsed time : 0 sec
# Testing // Epoch 106 //  Total cost = 29082.62  RMSE = 1.06002 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 107 //  Total cost = 45302.13 Elapsed time : 0 sec
# Testing // Epoch 107 //  Total cost = 29068.29  RMSE = 1.05968 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 108 //  Total cost = 44991.16 Elapsed time : 0 sec
# Testing // Epoch 108 //  Total cost = 29055.11  RMSE = 1.05936 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 109 //  Total cost = 44695.17 Elapsed time : 0 sec
# Testing // Epoch 109 //  Total cost = 29043.19  RMSE = 1.05907 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 110 //  Total cost = 44396.82 Elapsed time : 0 sec
# Testing // Epoch 110 //  Total cost = 29041.30  RMSE = 1.05898 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 111 //  Total cost = 44091.34 Elapsed time : 0 sec
# Testing // Epoch 111 //  Total cost = 29034.93  RMSE = 1.05879 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 112 //  Total cost = 43798.13 Elapsed time : 0 sec
# Testing // Epoch 112 //  Total cost = 29025.49  RMSE = 1.05855 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 113 //  Total cost = 43497.45 Elapsed time : 0 sec
# Testing // Epoch 113 //  Total cost = 29005.49  RMSE = 1.05810 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 114 //  Total cost = 43200.25 Elapsed time : 0 sec
# Testing // Epoch 114 //  Total cost = 29001.19  RMSE = 1.05795 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 115 //  Total cost = 42898.45 Elapsed time : 0 sec
# Testing // Epoch 115 //  Total cost = 28990.93  RMSE = 1.05769 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 116 //  Total cost = 42608.28 Elapsed time : 0 sec
# Testing // Epoch 116 //  Total cost = 28991.83  RMSE = 1.05764 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 117 //  Total cost = 42308.00 Elapsed time : 0 sec
# Testing // Epoch 117 //  Total cost = 28975.15  RMSE = 1.05725 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 118 //  Total cost = 42015.36 Elapsed time : 0 sec
# Testing // Epoch 118 //  Total cost = 28970.00  RMSE = 1.05709 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 119 //  Total cost = 41718.72 Elapsed time : 0 sec
# Testing // Epoch 119 //  Total cost = 28956.12  RMSE = 1.05676 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 120 //  Total cost = 41426.72 Elapsed time : 0 sec
# Testing // Epoch 120 //  Total cost = 28946.94  RMSE = 1.05652 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 121 //  Total cost = 41136.19 Elapsed time : 0 sec
# Testing // Epoch 121 //  Total cost = 28930.88  RMSE = 1.05614 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 122 //  Total cost = 40849.58 Elapsed time : 0 sec
# Testing // Epoch 122 //  Total cost = 28930.98  RMSE = 1.05608 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 123 //  Total cost = 40570.91 Elapsed time : 0 sec
# Testing // Epoch 123 //  Total cost = 28929.52  RMSE = 1.05598 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 124 //  Total cost = 40270.11 Elapsed time : 0 sec
# Testing // Epoch 124 //  Total cost = 28922.95  RMSE = 1.05579 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 125 //  Total cost = 39986.75 Elapsed time : 0 sec
# Testing // Epoch 125 //  Total cost = 28917.97  RMSE = 1.05562 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 126 //  Total cost = 39696.83 Elapsed time : 0 sec
# Testing // Epoch 126 //  Total cost = 28910.16  RMSE = 1.05540 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 127 //  Total cost = 39421.75 Elapsed time : 0 sec
# Testing // Epoch 127 //  Total cost = 28891.86  RMSE = 1.05498 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 128 //  Total cost = 39135.02 Elapsed time : 0 sec
# Testing // Epoch 128 //  Total cost = 28876.65  RMSE = 1.05462 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 129 //  Total cost = 38856.42 Elapsed time : 0 sec
# Testing // Epoch 129 //  Total cost = 28873.14  RMSE = 1.05448 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 130 //  Total cost = 38575.61 Elapsed time : 0 sec
# Testing // Epoch 130 //  Total cost = 28870.80  RMSE = 1.05437 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 131 //  Total cost = 38291.97 Elapsed time : 0 sec
# Testing // Epoch 131 //  Total cost = 28860.61  RMSE = 1.05410 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 132 //  Total cost = 38008.53 Elapsed time : 0 sec
# Testing // Epoch 132 //  Total cost = 28852.56  RMSE = 1.05388 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 133 //  Total cost = 37731.70 Elapsed time : 0 sec
# Testing // Epoch 133 //  Total cost = 28837.86  RMSE = 1.05352 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 134 //  Total cost = 37460.43 Elapsed time : 0 sec
# Testing // Epoch 134 //  Total cost = 28828.79  RMSE = 1.05328 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 135 //  Total cost = 37179.02 Elapsed time : 0 sec
# Testing // Epoch 135 //  Total cost = 28829.75  RMSE = 1.05323 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 136 //  Total cost = 36902.66 Elapsed time : 0 sec
# Testing // Epoch 136 //  Total cost = 28829.12  RMSE = 1.05314 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 137 //  Total cost = 36633.17 Elapsed time : 0 sec
# Testing // Epoch 137 //  Total cost = 28821.80  RMSE = 1.05293 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 138 //  Total cost = 36364.98 Elapsed time : 0 sec
# Testing // Epoch 138 //  Total cost = 28802.30  RMSE = 1.05248 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 139 //  Total cost = 36089.95 Elapsed time : 0 sec
# Testing // Epoch 139 //  Total cost = 28791.15  RMSE = 1.05220 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 140 //  Total cost = 35823.87 Elapsed time : 0 sec
# Testing // Epoch 140 //  Total cost = 28787.88  RMSE = 1.05206 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 141 //  Total cost = 35553.18 Elapsed time : 0 sec
# Testing // Epoch 141 //  Total cost = 28777.82  RMSE = 1.05179 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 142 //  Total cost = 35284.45 Elapsed time : 0 sec
# Testing // Epoch 142 //  Total cost = 28767.21  RMSE = 1.05152 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 143 //  Total cost = 35021.53 Elapsed time : 0 sec
# Testing // Epoch 143 //  Total cost = 28767.69  RMSE = 1.05145 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 144 //  Total cost = 34755.76 Elapsed time : 0 sec
# Testing // Epoch 144 //  Total cost = 28755.46  RMSE = 1.05115 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 145 //  Total cost = 34497.25 Elapsed time : 0 sec
# Testing // Epoch 145 //  Total cost = 28742.78  RMSE = 1.05083 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 146 //  Total cost = 34231.88 Elapsed time : 0 sec
# Testing // Epoch 146 //  Total cost = 28735.32  RMSE = 1.05061 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 147 //  Total cost = 33973.57 Elapsed time : 0 sec
# Testing // Epoch 147 //  Total cost = 28730.31  RMSE = 1.05044 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 148 //  Total cost = 33709.19 Elapsed time : 0 sec
# Testing // Epoch 148 //  Total cost = 28726.00  RMSE = 1.05028 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 149 //  Total cost = 33459.58 Elapsed time : 0 sec
# Testing // Epoch 149 //  Total cost = 28718.96  RMSE = 1.05007 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 150 //  Total cost = 33195.41 Elapsed time : 0 sec
# Testing // Epoch 150 //  Total cost = 28711.62  RMSE = 1.04986 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 151 //  Total cost = 32956.10 Elapsed time : 0 sec
# Testing // Epoch 151 //  Total cost = 28706.08  RMSE = 1.04969 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 152 //  Total cost = 32710.53 Elapsed time : 0 sec
# Testing // Epoch 152 //  Total cost = 28693.91  RMSE = 1.04938 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 153 //  Total cost = 32462.14 Elapsed time : 0 sec
# Testing // Epoch 153 //  Total cost = 28686.43  RMSE = 1.04917 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 154 //  Total cost = 32221.93 Elapsed time : 0 sec
# Testing // Epoch 154 //  Total cost = 28677.05  RMSE = 1.04892 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 155 //  Total cost = 31982.21 Elapsed time : 0 sec
# Testing // Epoch 155 //  Total cost = 28667.84  RMSE = 1.04867 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 156 //  Total cost = 31743.47 Elapsed time : 0 sec
# Testing // Epoch 156 //  Total cost = 28662.13  RMSE = 1.04849 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 157 //  Total cost = 31502.12 Elapsed time : 0 sec
# Testing // Epoch 157 //  Total cost = 28651.35  RMSE = 1.04821 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 158 //  Total cost = 31263.04 Elapsed time : 0 sec
# Testing // Epoch 158 //  Total cost = 28645.31  RMSE = 1.04802 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 159 //  Total cost = 31031.69 Elapsed time : 0 sec
# Testing // Epoch 159 //  Total cost = 28644.50  RMSE = 1.04793 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 160 //  Total cost = 30787.69 Elapsed time : 0 sec
# Testing // Epoch 160 //  Total cost = 28643.54  RMSE = 1.04784 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 161 //  Total cost = 30559.96 Elapsed time : 0 sec
# Testing // Epoch 161 //  Total cost = 28638.60  RMSE = 1.04767 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 162 //  Total cost = 30323.02 Elapsed time : 0 sec
# Testing // Epoch 162 //  Total cost = 28632.98  RMSE = 1.04749 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 163 //  Total cost = 30093.35 Elapsed time : 0 sec
# Testing // Epoch 163 //  Total cost = 28623.00  RMSE = 1.04723 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 164 //  Total cost = 29865.31 Elapsed time : 0 sec
# Testing // Epoch 164 //  Total cost = 28612.48  RMSE = 1.04695 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 165 //  Total cost = 29628.73 Elapsed time : 0 sec
# Testing // Epoch 165 //  Total cost = 28609.23  RMSE = 1.04682 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 166 //  Total cost = 29406.04 Elapsed time : 0 sec
# Testing // Epoch 166 //  Total cost = 28593.48  RMSE = 1.04645 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 167 //  Total cost = 29174.04 Elapsed time : 0 sec
# Testing // Epoch 167 //  Total cost = 28585.64  RMSE = 1.04622 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 168 //  Total cost = 28951.15 Elapsed time : 0 sec
# Testing // Epoch 168 //  Total cost = 28571.92  RMSE = 1.04589 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 169 //  Total cost = 28723.22 Elapsed time : 0 sec
# Testing // Epoch 169 //  Total cost = 28566.81  RMSE = 1.04572 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 170 //  Total cost = 28499.25 Elapsed time : 0 sec
# Testing // Epoch 170 //  Total cost = 28563.08  RMSE = 1.04557 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 171 //  Total cost = 28277.93 Elapsed time : 0 sec
# Testing // Epoch 171 //  Total cost = 28563.24  RMSE = 1.04550 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 172 //  Total cost = 28053.93 Elapsed time : 0 sec
# Testing // Epoch 172 //  Total cost = 28555.56  RMSE = 1.04528 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 173 //  Total cost = 27834.76 Elapsed time : 0 sec
# Testing // Epoch 173 //  Total cost = 28551.41  RMSE = 1.04513 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 174 //  Total cost = 27618.27 Elapsed time : 0 sec
# Testing // Epoch 174 //  Total cost = 28545.28  RMSE = 1.04494 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 175 //  Total cost = 27395.17 Elapsed time : 0 sec
# Testing // Epoch 175 //  Total cost = 28535.01  RMSE = 1.04467 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 176 //  Total cost = 27183.59 Elapsed time : 0 sec
# Testing // Epoch 176 //  Total cost = 28523.20  RMSE = 1.04437 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 177 //  Total cost = 26965.31 Elapsed time : 0 sec
# Testing // Epoch 177 //  Total cost = 28509.91  RMSE = 1.04404 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 178 //  Total cost = 26756.35 Elapsed time : 0 sec
# Testing // Epoch 178 //  Total cost = 28502.40  RMSE = 1.04383 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 179 //  Total cost = 26540.41 Elapsed time : 0 sec
# Testing // Epoch 179 //  Total cost = 28496.85  RMSE = 1.04365 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 180 //  Total cost = 26329.25 Elapsed time : 0 sec
# Testing // Epoch 180 //  Total cost = 28496.90  RMSE = 1.04358 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 181 //  Total cost = 26117.20 Elapsed time : 0 sec
# Testing // Epoch 181 //  Total cost = 28488.52  RMSE = 1.04335 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 182 //  Total cost = 25912.24 Elapsed time : 0 sec
# Testing // Epoch 182 //  Total cost = 28481.39  RMSE = 1.04314 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 183 //  Total cost = 25703.81 Elapsed time : 0 sec
# Testing // Epoch 183 //  Total cost = 28477.49  RMSE = 1.04299 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 184 //  Total cost = 25495.80 Elapsed time : 0 sec
# Testing // Epoch 184 //  Total cost = 28473.15  RMSE = 1.04283 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 185 //  Total cost = 25290.71 Elapsed time : 0 sec
# Testing // Epoch 185 //  Total cost = 28469.46  RMSE = 1.04269 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 186 //  Total cost = 25089.57 Elapsed time : 0 sec
# Testing // Epoch 186 //  Total cost = 28459.50  RMSE = 1.04243 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 187 //  Total cost = 24886.41 Elapsed time : 0 sec
# Testing // Epoch 187 //  Total cost = 28448.54  RMSE = 1.04215 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 188 //  Total cost = 24689.95 Elapsed time : 0 sec
# Testing // Epoch 188 //  Total cost = 28441.31  RMSE = 1.04194 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 189 //  Total cost = 24486.42 Elapsed time : 0 sec
# ...
# Training // Epoch 437 //  Total cost = 5221.52 Elapsed time : 0 sec
# Testing // Epoch 437 //  Total cost = 27721.53  RMSE = 1.02124 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 438 //  Total cost = 5202.29 Elapsed time : 0 sec
# Testing // Epoch 438 //  Total cost = 27720.56  RMSE = 1.02122 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 439 //  Total cost = 5183.36 Elapsed time : 0 sec
# Testing // Epoch 439 //  Total cost = 27719.97  RMSE = 1.02121 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 440 //  Total cost = 5164.40 Elapsed time : 0 sec
# Testing // Epoch 440 //  Total cost = 27718.14  RMSE = 1.02118 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 441 //  Total cost = 5145.76 Elapsed time : 0 sec
# Testing // Epoch 441 //  Total cost = 27715.82  RMSE = 1.02114 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 442 //  Total cost = 5127.61 Elapsed time : 0 sec
# Testing // Epoch 442 //  Total cost = 27715.16  RMSE = 1.02113 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 443 //  Total cost = 5109.18 Elapsed time : 0 sec
# Testing // Epoch 443 //  Total cost = 27715.28  RMSE = 1.02113 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 444 //  Total cost = 5090.97 Elapsed time : 0 sec
# Testing // Epoch 444 //  Total cost = 27714.11  RMSE = 1.02112 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 445 //  Total cost = 5072.52 Elapsed time : 0 sec
# Testing // Epoch 445 //  Total cost = 27711.99  RMSE = 1.02108 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 446 //  Total cost = 5055.17 Elapsed time : 0 sec
# Testing // Epoch 446 //  Total cost = 27710.76  RMSE = 1.02106 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 447 //  Total cost = 5037.25 Elapsed time : 0 sec
# Testing // Epoch 447 //  Total cost = 27708.75  RMSE = 1.02103 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 448 //  Total cost = 5019.82 Elapsed time : 0 sec
# Testing // Epoch 448 //  Total cost = 27709.35  RMSE = 1.02104 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 449 //  Total cost = 5002.00 Elapsed time : 0 sec
# Testing // Epoch 449 //  Total cost = 27710.88  RMSE = 1.02108 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 450 //  Total cost = 4984.92 Elapsed time : 0 sec
# Testing // Epoch 450 //  Total cost = 27709.96  RMSE = 1.02106 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 451 //  Total cost = 4968.49 Elapsed time : 0 sec
# Testing // Epoch 451 //  Total cost = 27706.90  RMSE = 1.02101 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 452 //  Total cost = 4951.96 Elapsed time : 0 sec
# Testing // Epoch 452 //  Total cost = 27704.70  RMSE = 1.02097 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 453 //  Total cost = 4935.32 Elapsed time : 0 sec
# Testing // Epoch 453 //  Total cost = 27703.81  RMSE = 1.02095 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 454 //  Total cost = 4919.86 Elapsed time : 0 sec
# Testing // Epoch 454 //  Total cost = 27703.44  RMSE = 1.02095 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 455 //  Total cost = 4903.91 Elapsed time : 0 sec
# Testing // Epoch 455 //  Total cost = 27701.98  RMSE = 1.02093 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 456 //  Total cost = 4887.64 Elapsed time : 0 sec
# Testing // Epoch 456 //  Total cost = 27700.80  RMSE = 1.02091 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 457 //  Total cost = 4872.13 Elapsed time : 0 sec
# Testing // Epoch 457 //  Total cost = 27700.82  RMSE = 1.02092 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 458 //  Total cost = 4856.12 Elapsed time : 0 sec
# Testing // Epoch 458 //  Total cost = 27700.61  RMSE = 1.02092 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 459 //  Total cost = 4840.72 Elapsed time : 0 sec
# Testing // Epoch 459 //  Total cost = 27699.32  RMSE = 1.02090 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 460 //  Total cost = 4825.28 Elapsed time : 0 sec
# Testing // Epoch 460 //  Total cost = 27697.47  RMSE = 1.02087 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 461 //  Total cost = 4810.14 Elapsed time : 0 sec
# Testing // Epoch 461 //  Total cost = 27695.53  RMSE = 1.02083 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 462 //  Total cost = 4794.98 Elapsed time : 0 sec
# Testing // Epoch 462 //  Total cost = 27695.31  RMSE = 1.02083 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 463 //  Total cost = 4779.58 Elapsed time : 0 sec
# Testing // Epoch 463 //  Total cost = 27693.58  RMSE = 1.02080 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 464 //  Total cost = 4764.73 Elapsed time : 0 sec
# Testing // Epoch 464 //  Total cost = 27692.45  RMSE = 1.02079 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 465 //  Total cost = 4749.72 Elapsed time : 0 sec
# Testing // Epoch 465 //  Total cost = 27692.15  RMSE = 1.02079 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 466 //  Total cost = 4735.31 Elapsed time : 0 sec
# Testing // Epoch 466 //  Total cost = 27691.37  RMSE = 1.02078 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 467 //  Total cost = 4720.45 Elapsed time : 0 sec
# Testing // Epoch 467 //  Total cost = 27690.93  RMSE = 1.02078 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 468 //  Total cost = 4706.29 Elapsed time : 0 sec
# Testing // Epoch 468 //  Total cost = 27690.29  RMSE = 1.02077 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 469 //  Total cost = 4691.86 Elapsed time : 0 sec
# Testing // Epoch 469 //  Total cost = 27689.37  RMSE = 1.02076 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 470 //  Total cost = 4677.31 Elapsed time : 0 sec
# Testing // Epoch 470 //  Total cost = 27686.56  RMSE = 1.02071 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 471 //  Total cost = 4663.32 Elapsed time : 0 sec
# Testing // Epoch 471 //  Total cost = 27685.42  RMSE = 1.02069 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 472 //  Total cost = 4649.26 Elapsed time : 0 sec
# Testing // Epoch 472 //  Total cost = 27683.65  RMSE = 1.02067 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 473 //  Total cost = 4635.35 Elapsed time : 0 sec
# Testing // Epoch 473 //  Total cost = 27683.42  RMSE = 1.02067 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 474 //  Total cost = 4621.54 Elapsed time : 0 sec
# Testing // Epoch 474 //  Total cost = 27682.62  RMSE = 1.02066 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 475 //  Total cost = 4607.66 Elapsed time : 0 sec
# Testing // Epoch 475 //  Total cost = 27681.82  RMSE = 1.02065 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 476 //  Total cost = 4593.86 Elapsed time : 0 sec
# Testing // Epoch 476 //  Total cost = 27681.29  RMSE = 1.02065 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 477 //  Total cost = 4580.28 Elapsed time : 0 sec
# Testing // Epoch 477 //  Total cost = 27679.81  RMSE = 1.02062 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 478 //  Total cost = 4566.95 Elapsed time : 0 sec
# Testing // Epoch 478 //  Total cost = 27679.76  RMSE = 1.02063 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 479 //  Total cost = 4553.44 Elapsed time : 0 sec
# Testing // Epoch 479 //  Total cost = 27679.35  RMSE = 1.02063 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 480 //  Total cost = 4540.55 Elapsed time : 0 sec
# Testing // Epoch 480 //  Total cost = 27676.91  RMSE = 1.02059 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 481 //  Total cost = 4527.33 Elapsed time : 0 sec
# Testing // Epoch 481 //  Total cost = 27674.08  RMSE = 1.02054 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 482 //  Total cost = 4514.06 Elapsed time : 0 sec
# Testing // Epoch 482 //  Total cost = 27673.77  RMSE = 1.02054 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 483 //  Total cost = 4501.07 Elapsed time : 0 sec
# Testing // Epoch 483 //  Total cost = 27674.30  RMSE = 1.02056 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 484 //  Total cost = 4488.22 Elapsed time : 0 sec
# Testing // Epoch 484 //  Total cost = 27673.73  RMSE = 1.02055 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 485 //  Total cost = 4475.40 Elapsed time : 0 sec
# Testing // Epoch 485 //  Total cost = 27671.52  RMSE = 1.02052 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 486 //  Total cost = 4462.80 Elapsed time : 0 sec
# Testing // Epoch 486 //  Total cost = 27669.88  RMSE = 1.02049 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 487 //  Total cost = 4450.15 Elapsed time : 0 sec
# Testing // Epoch 487 //  Total cost = 27669.51  RMSE = 1.02050 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 488 //  Total cost = 4437.74 Elapsed time : 0 sec
# Testing // Epoch 488 //  Total cost = 27669.87  RMSE = 1.02051 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 489 //  Total cost = 4425.17 Elapsed time : 0 sec
# Testing // Epoch 489 //  Total cost = 27667.97  RMSE = 1.02047 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 490 //  Total cost = 4412.86 Elapsed time : 0 sec
# Testing // Epoch 490 //  Total cost = 27667.21  RMSE = 1.02047 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 491 //  Total cost = 4400.71 Elapsed time : 0 sec
# Testing // Epoch 491 //  Total cost = 27665.37  RMSE = 1.02044 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 492 //  Total cost = 4388.56 Elapsed time : 0 sec
# Testing // Epoch 492 //  Total cost = 27663.96  RMSE = 1.02042 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 493 //  Total cost = 4376.40 Elapsed time : 0 sec
# Testing // Epoch 493 //  Total cost = 27662.36  RMSE = 1.02039 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 494 //  Total cost = 4364.46 Elapsed time : 0 sec
# Testing // Epoch 494 //  Total cost = 27661.18  RMSE = 1.02038 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 495 //  Total cost = 4352.62 Elapsed time : 0 sec
# Testing // Epoch 495 //  Total cost = 27660.87  RMSE = 1.02039 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 496 //  Total cost = 4340.72 Elapsed time : 0 sec
# Testing // Epoch 496 //  Total cost = 27659.89  RMSE = 1.02038 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 497 //  Total cost = 4329.03 Elapsed time : 0 sec
# Testing // Epoch 497 //  Total cost = 27658.88  RMSE = 1.02036 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 498 //  Total cost = 4317.54 Elapsed time : 0 sec
# Testing // Epoch 498 //  Total cost = 27658.58  RMSE = 1.02036 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 499 //  Total cost = 4305.84 Elapsed time : 0 sec
# Testing // Epoch 499 //  Total cost = 27657.68  RMSE = 1.02035 Elapsed time : 0 sec
# ====================================================================================================
