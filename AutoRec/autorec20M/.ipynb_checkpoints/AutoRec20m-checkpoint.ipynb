# %% [markdown]
# # Import the packages and check connection to bucket

# %%
from google.cloud import storage
import pandas as pd ## for dataset and eda
import numpy as np ## for eda
from datetime import datetime
from tqdm import tqdm

# %%
bucket_name = "firstprojectdl"

storage_client = storage.Client()
bucket = storage_client.get_bucket(bucket_name)

print(bucket)
print('Great, we now have access to our first bucket on google cloud storage where we put our data')
# Out:
# <Bucket: firstprojectdl>
# Great, we now have access to our first bucket on google cloud storage where we put our data

# %%
from google.cloud import storage
import pandas as pd

bucket_name = "firstprojectdl"

storage_client = storage.Client()
bucket = storage_client.get_bucket(bucket_name)

# When you have your files in a subfolder of the bucket.
my_prefix = "data/movieLens/movieLens20M/" # the name of the subfolder
blobs = bucket.list_blobs(prefix = my_prefix, delimiter = '/')

dfDict = {}
dateparse = lambda x: datetime.utcfromtimestamp(int(x)).strftime('%Y-%m-%d %H:%M:%S')

for blob in blobs:
    if(blob.name != my_prefix): # ignoring the subfolder itself 
        file_name = blob.name.replace(my_prefix, "")
        blob.download_to_filename(file_name) # download the file to the machine
        print(file_name)
        if file_name =='ratings20M.dat':
            df = pd.read_csv(file_name, sep=',', 
                            names=['user_id', 'movie_id', 'rating', 'timestamp'],
                            skiprows = 1, 
                            parse_dates=['timestamp'], 
                            date_parser=dateparse) # load the rating data
# Out:
# ratings20M.dat

# %% [markdown]
# ## Memory Error with 20 million dataset then we will only read the file with first 2.5 million rows

# %%
df.head()
# Out:
#    user_id  movie_id  rating           timestamp
# 0        1         2     3.5 2005-04-02 23:53:47
# 1        1        29     3.5 2005-04-02 23:31:16
# 2        1        32     3.5 2005-04-02 23:33:39
# 3        1        47     3.5 2005-04-02 23:32:07
# 4        1        50     3.5 2005-04-02 23:29:40

# %%
df = df.loc[(df['movie_id'].isin(range(15000))) & (df['user_id'].isin(range(15000))), :]

# %%
df.head()
# Out:
#    user_id  movie_id  rating           timestamp
# 0        1         2     3.5 2005-04-02 23:53:47
# 1        1        29     3.5 2005-04-02 23:31:16
# 2        1        32     3.5 2005-04-02 23:33:39
# 3        1        47     3.5 2005-04-02 23:32:07
# 4        1        50     3.5 2005-04-02 23:29:40

# %%
listMovies = np.sort(df.movie_id.unique())
ind = 0
for movies in tqdm(listMovies):
    df.loc[df['movie_id'] == movies, 'movie_id'] = ind
    ind += 1
# Out:
# 100%|██████████| 8190/8190 [01:12<00:00, 112.28it/s]

# %%
listMovies = df.movie_id.unique()
len(listMovies)
# Out:
# 8190

# %%
listMovies = df.movie_id.unique()
len(listMovies)
# Out:
# 8190

# %%
listMovies.sort()

# %%
df.to_csv('ratings2.5M.dat')

# %%
df.head()
# Out:
#    user_id  movie_id  rating           timestamp
# 0        1         1     3.5 2005-04-02 23:53:47
# 1        1        28     3.5 2005-04-02 23:31:16
# 2        1        31     3.5 2005-04-02 23:33:39
# 3        1        46     3.5 2005-04-02 23:32:07
# 4        1        49     3.5 2005-04-02 23:29:40

# %%
# Out:
# (1960385, 4)

# %%
num_users = df.user_id.unique().shape[0]
print(f'The datasets presents {num_users} users')
# Out:
# The datasets presents 14998 users

# %%
num_ratings = df.rating.shape[0]
print(f'The datasets presents {num_ratings} distinct ratings')
# Out:
# The datasets presents 1960385 distinct ratings

# %%
num_items = df.movie_id.unique().shape[0]
print(f'The datasets presents {num_items} items')
# Out:
# The datasets presents 8190 items

# %%
df.movie_id.unique()
# Out:
# array([   1,   28,   31, ..., 7205, 7697, 5945])

# %%
with open('ratings2.5M.dat') as infile:
  with open('ratings2.5MNew.dat', 'w') as outfile:
    for line in infile:
      fields = line.split(',')
      outfile.write('::'.join(fields))

# %%
fp = open("ratings2.5MNew.dat")
lines = fp.readlines()

# %%
lines[0]
# Out:
# '::user_id::movie_id::rating::timestamp\n'

# %%
import numpy as np

# %%
# Comet ML for experiment logging
from comet_ml import Experiment

# %%
# Import packages
import tensorflow as tf
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# Set random seed
tf.random.set_random_seed(1994)
np.random.seed(1994)

# %%
def read_rating(num_users, num_items, num_total_ratings, a, b, train_ratio):
    """
    Function to read in the ratings data
    :param path: path to ratings data
    :param num_users: number of users
    :param num_items: number of items
    :param num_total_ratings: number of total ratings
    :param a: positive rating (1)
    :param b: negative rating (0)
    :param train_ratio: ratio that splits train and test sets
    """
    fp = open("ratings2.5MNew.dat")

    user_train_set = set()
    user_test_set = set()
    item_train_set = set()
    item_test_set = set()
    R = np.zeros((num_users, num_items))
    mask_R = np.zeros((num_users, num_items))
    C = np.ones((num_users, num_items)) * b

    train_R = np.zeros((num_users, num_items))
    test_R = np.zeros((num_users, num_items))

    train_mask_R = np.zeros((num_users, num_items))
    test_mask_R = np.zeros((num_users, num_items))

    random_perm_idx = np.random.permutation(num_total_ratings)
    train_idx = random_perm_idx[0:int(num_total_ratings * train_ratio)]
    test_idx = random_perm_idx[int(num_total_ratings * train_ratio):]

    num_train_ratings = len(train_idx)
    num_test_ratings = len(test_idx)

    lines = fp.readlines()
    for line in lines[1:]:
        _, user, item, rating, _ = line.split("::")
        user_idx = int(user) - 1
        item_idx = int(item) - 1
        R[user_idx, item_idx] = float(rating)
        mask_R[user_idx, item_idx] = 1
        C[user_idx, item_idx] = a

    # Training set
    for itr in train_idx:
        line = lines[itr]
        _, user, item, rating, _ = line.split("::")
        if (user == 'user_id') | (item == 'movie_id') | (rating == 'rating'):
            continue
        user_idx = int(user) - 1
        item_idx = int(item) - 1
        train_R[user_idx, item_idx] = float(rating)
        train_mask_R[user_idx, item_idx] = 1

        user_train_set.add(user_idx)
        item_train_set.add(item_idx)

    # Test set
    for itr in test_idx:
        line = lines[itr]
        _, user, item, rating, _ = line.split("::")
        if (user == 'user_id') | (item == 'movie_id') | (rating == 'rating'):
            continue
        user_idx = int(user) - 1
        item_idx = int(item) - 1
        test_R[user_idx, item_idx] = float(rating)
        test_mask_R[user_idx, item_idx] = 1

        user_test_set.add(user_idx)
        item_test_set.add(item_idx)

    return R, mask_R, C, train_R, train_mask_R, test_R, test_mask_R, num_train_ratings, num_test_ratings, \
           user_train_set, item_train_set, user_test_set, item_test_set

# %%
data_name = 'ml-2.5M'
num_users = 14999
num_items = 8190
num_total_ratings = 1960385
# Data is split into random 75% - 25% train-test sets
train_ratio = 0.75

# %%
R, mask_R, C, train_R, train_mask_R, test_R, test_mask_R, num_train_ratings, num_test_ratings, \
user_train_set, item_train_set, user_test_set, item_test_set = read_rating(num_users, num_items, num_total_ratings, 1, 0, train_ratio)

# %%
# Get hyper-parameters
hyper_params = {
    "hidden_neuron": 500,
    "lambda_value": 1,
    "epochs": 500,
    "batch_size": 512,
    "optimizer": "Adam",
    "learning_rate": 0.001,
    "random_seed": 1994
}

# %%
# Import packages
import tensorflow as tf
import time
import numpy as np
import os
import math

# %%
class AutoRec:
    """
    Function to define the AutoRec model class
    """
    def __init__(self, sess, args,
                 num_users, num_items,
                 R, mask_R, C, train_R, train_mask_R, test_R, test_mask_R, num_train_ratings, num_test_ratings,
                 user_train_set, item_train_set, user_test_set, item_test_set,
                 result_path):

        self.sess = sess
        self.args = args

        self.num_users = num_users
        self.num_items = num_items

        self.R = R
        self.mask_R = mask_R
        self.C = C
        self.train_R = train_R
        self.train_mask_R = train_mask_R
        self.test_R = test_R
        self.test_mask_R = test_mask_R
        self.num_train_ratings = num_train_ratings
        self.num_test_ratings = num_test_ratings

        self.user_train_set = user_train_set
        self.item_train_set = item_train_set
        self.user_test_set = user_test_set
        self.item_test_set = item_test_set

        self.hidden_neuron = args['hidden_neuron']
        self.train_epoch = args['train_epoch']
        self.batch_size = args['batch_size']
        self.num_batch = int(math.ceil(self.num_users / float(self.batch_size)))

        self.base_lr = args['base_lr']
        self.optimizer_method = args['optimizer_method']
        self.display_step = args['display_step']
        self.random_seed = args['random_seed']

        self.global_step = tf.Variable(0, trainable=False)
        self.decay_epoch_step = args['decay_epoch_step']
        self.decay_step = self.decay_epoch_step * self.num_batch
        self.lr = tf.compat.v1.train.exponential_decay(self.base_lr, self.global_step,
                                                       self.decay_step, 0.96, staircase=True)
        self.lambda_value = args['lambda_value']

        self.train_cost_list = []
        self.test_cost_list = []
        self.test_rmse_list = []

        self.result_path = result_path
        self.grad_clip = args['grad_clip']

    def run(self, experiment):
        """
        Function to run AutoRec
        :param experiment: CometML Experiment function
        """
        # Build AutoRec
        self.prepare_model()
        init = tf.compat.v1.global_variables_initializer()
        self.sess.run(init)

        # Train and evaluate AutoRec for all epochs
        for epoch_itr in range(self.train_epoch):
            experiment.set_step(epoch_itr)
            self.train_model(epoch_itr,experiment)
            self.test_model(epoch_itr, experiment)

        # Log results
        self.make_records()

    def prepare_model(self):
        """
        Function to build AutoRec
        """
        self.input_R = tf.compat.v1.placeholder(dtype=tf.float32,
                                                shape=[None, self.num_items],
                                                name="input_R")
        self.input_mask_R = tf.compat.v1.placeholder(dtype=tf.float32,
                                                     shape=[None, self.num_items],
                                                     name="input_mask_R")

        V = tf.compat.v1.get_variable(name="V", initializer=tf.compat.v1.truncated_normal(
            shape=[self.num_items, self.hidden_neuron],
            mean=0, stddev=0.03), dtype=tf.float32)
        W = tf.compat.v1.get_variable(name="W", initializer=tf.compat.v1.truncated_normal(
            shape=[self.hidden_neuron, self.num_items],
            mean=0, stddev=0.03), dtype=tf.float32)
        mu = tf.compat.v1.get_variable(name="mu", initializer=tf.zeros(shape=self.hidden_neuron), dtype=tf.float32)
        b = tf.compat.v1.get_variable(name="b", initializer=tf.zeros(shape=self.num_items), dtype=tf.float32)

        pre_Encoder = tf.matmul(self.input_R, V) + mu
        self.Encoder = tf.nn.sigmoid(pre_Encoder)
        pre_Decoder = tf.matmul(self.Encoder, W) + b
        self.Decoder = tf.identity(pre_Decoder)

        pre_rec_cost = tf.multiply((self.input_R - self.Decoder), self.input_mask_R)
        rec_cost = tf.square(self.l2_norm(pre_rec_cost))
        pre_reg_cost = tf.square(self.l2_norm(W)) + tf.square(self.l2_norm(V))
        reg_cost = self.lambda_value * 0.5 * pre_reg_cost

        self.cost = rec_cost + reg_cost

        if self.optimizer_method == "Adam":
            optimizer = tf.compat.v1.train.AdamOptimizer(self.lr)
        elif self.optimizer_method == "RMSProp":
            optimizer = tf.compat.v1.train.RMSPropOptimizer(self.lr)
        else:
            raise ValueError("Optimizer Key ERROR")

        if self.grad_clip:
            gvs = optimizer.compute_gradients(self.cost)
            capped_gvs = [(tf.clip_by_value(grad, -5., 5.), var) for grad, var in gvs]
            self.optimizer = optimizer.apply_gradients(capped_gvs, global_step=self.global_step)
        else:
            self.optimizer = optimizer.minimize(self.cost, global_step=self.global_step)

    def train_model(self, itr, experiment):
        """
        Function to train AutoRec
        :param itr: Current iteration
        :param experiment: CometML experiment
        """
        start_time = time.time()
        random_perm_doc_idx = np.random.permutation(self.num_users)

        batch_cost = 0
        for i in range(self.num_batch):
            if i == self.num_batch - 1:
                batch_set_idx = random_perm_doc_idx[i * self.batch_size:]
            elif i < self.num_batch - 1:
                batch_set_idx = random_perm_doc_idx[i * self.batch_size: (i + 1) * self.batch_size]

            _, Cost = self.sess.run(
                [self.optimizer, self.cost],
                feed_dict={self.input_R: self.train_R[batch_set_idx, :],
                           self.input_mask_R: self.train_mask_R[batch_set_idx, :]})

            batch_cost = batch_cost + Cost
        self.train_cost_list.append(batch_cost)

        if (itr + 1) % self.display_step == 0:

            print("Training //", "Epoch %d //" % (itr), " Total cost = {:.2f}".format(batch_cost),
                  "Elapsed time : %d sec" % (time.time() - start_time))

        experiment.log_metric("loss", batch_cost, step=itr)

    def test_model(self, itr, experiment):
        """
        Function to evaluate AutoRec
        :param itr: Current iteration
        :param experiment: CometML experiment
        """
        start_time = time.time()
        Cost, Decoder = self.sess.run(
            [self.cost, self.Decoder],
            feed_dict={self.input_R: self.test_R,
                       self.input_mask_R: self.test_mask_R})

        self.test_cost_list.append(Cost)

        if (itr + 1) % self.display_step == 0:
            Estimated_R = Decoder.clip(min=1, max=5)
            unseen_user_test_list = list(self.user_test_set - self.user_train_set)
            unseen_item_test_list = list(self.item_test_set - self.item_train_set)

            for user in unseen_user_test_list:
                for item in unseen_item_test_list:
                    if self.test_mask_R[user, item] == 1:  # exist in test set
                        Estimated_R[user, item] = 3

            pre_numerator = np.multiply((Estimated_R - self.test_R), self.test_mask_R)
            numerator = np.sum(np.square(pre_numerator))
            denominator = self.num_test_ratings
            RMSE = np.sqrt(numerator / float(denominator))

            self.test_rmse_list.append(RMSE)

            print("Testing //", "Epoch %d //" % (itr), " Total cost = {:.2f}".format(Cost),
                  " RMSE = {:.5f}".format(RMSE),
                  "Elapsed time : %d sec" % (time.time() - start_time))
            print("=" * 100)

        experiment.log_metric("RMSE", RMSE, step=itr)

    def make_records(self):
        """
        Function to log results
        """
        if not os.path.exists(self.result_path):
            os.makedirs(self.result_path)

        basic_info = self.result_path + "basic_info.txt"
        train_record = self.result_path + "train_record.txt"
        test_record = self.result_path + "test_record.txt"

        with open(train_record, 'w') as f:
            f.write(str("Cost:"))
            f.write('\t')
            for itr in range(len(self.train_cost_list)):
                f.write(str(self.train_cost_list[itr]))
                f.write('\t')
            f.write('\n')

        with open(test_record, 'w') as g:
            g.write(str("Cost:"))
            g.write('\t')
            for itr in range(len(self.test_cost_list)):
                g.write(str(self.test_cost_list[itr]))
                g.write('\t')
            g.write('\n')

            g.write(str("RMSE:"))
            for itr in range(len(self.test_rmse_list)):
                g.write(str(self.test_rmse_list[itr]))
                g.write('\t')
            g.write('\n')

        #with open(basic_info, 'w') as h:
        #    h.write(str(self.args))

    def l2_norm(self, tensor):
        """
        Function to apply L2 normalization
        :param tensor: TensorFlow tensor
        """
        return tf.sqrt(tf.reduce_sum(tf.square(tensor)))

# %%
# Initialize TensorFlow Config
config = tf.compat.v1.ConfigProto()

# %%
experiment = Experiment(api_key="vV3GGUE8tetqNJuD2kGxVi1M9", project_name="autoencoders-movielens2.5M")
experiment.log_parameters(hyper_params)
# Out:
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/benichou/autoencoders-movielens100k/335bfcaa053248e7b8e970b24682bf82

# %%
args = {'hidden_neuron': 500, 'lambda_value':1, 'train_epoch': 500, 'batch_size': 512, 'optimizer_method': 'Adam', 'grad_clip': False, 'base_lr': 1e-3, 'decay_epoch_step': 50, 'random_seed':1994, 'display_step':1}

# %%
result_path = 'results/'

# %%
with tf.compat.v1.Session(config=config) as sess:
    # Define the AutoRec class from `AutoRec.py`
    AutoRec = AutoRec(sess, args,
                      num_users, num_items,
                      R, mask_R, C, train_R, train_mask_R, test_R, test_mask_R, num_train_ratings, num_test_ratings,
                      user_train_set, item_train_set, user_test_set, item_test_set,
                      result_path)
    # Run the AutoRec model
    AutoRec.run(experiment)
# Out:
# COMET ERROR: Failed to extract parameters from Optimizer.init()
# Training // Epoch 0 //  Total cost = 4719396.64 Elapsed time : 7 sec
# Testing // Epoch 0 //  Total cost = 765908.25  RMSE = 1.24734 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 1 //  Total cost = 1564239.07 Elapsed time : 6 sec
# Testing // Epoch 1 //  Total cost = 581948.88  RMSE = 1.08677 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 2 //  Total cost = 1438181.81 Elapsed time : 6 sec
# Testing // Epoch 2 //  Total cost = 531821.19  RMSE = 1.03873 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 3 //  Total cost = 1399633.07 Elapsed time : 6 sec
# Testing // Epoch 3 //  Total cost = 509665.81  RMSE = 1.01687 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 4 //  Total cost = 1365781.86 Elapsed time : 6 sec
# Testing // Epoch 4 //  Total cost = 497312.34  RMSE = 1.00453 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 5 //  Total cost = 1333254.08 Elapsed time : 6 sec
# Testing // Epoch 5 //  Total cost = 488337.50  RMSE = 0.99540 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 6 //  Total cost = 1304383.24 Elapsed time : 6 sec
# Testing // Epoch 6 //  Total cost = 482071.41  RMSE = 0.98902 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 7 //  Total cost = 1275449.57 Elapsed time : 7 sec
# Testing // Epoch 7 //  Total cost = 479356.59  RMSE = 0.98619 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 8 //  Total cost = 1249144.64 Elapsed time : 7 sec
# Testing // Epoch 8 //  Total cost = 473231.25  RMSE = 0.97985 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 9 //  Total cost = 1219746.92 Elapsed time : 6 sec
# Testing // Epoch 9 //  Total cost = 469988.03  RMSE = 0.97653 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 10 //  Total cost = 1193336.65 Elapsed time : 6 sec
# Testing // Epoch 10 //  Total cost = 465434.56  RMSE = 0.97171 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 11 //  Total cost = 1166322.10 Elapsed time : 7 sec
# Testing // Epoch 11 //  Total cost = 463777.38  RMSE = 0.97007 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 12 //  Total cost = 1140671.18 Elapsed time : 6 sec
# Testing // Epoch 12 //  Total cost = 460710.03  RMSE = 0.96674 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 13 //  Total cost = 1118741.70 Elapsed time : 6 sec
# Testing // Epoch 13 //  Total cost = 457106.25  RMSE = 0.96302 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 14 //  Total cost = 1093555.34 Elapsed time : 6 sec
# Testing // Epoch 14 //  Total cost = 455582.84  RMSE = 0.96128 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 15 //  Total cost = 1070785.30 Elapsed time : 7 sec
# Testing // Epoch 15 //  Total cost = 453254.19  RMSE = 0.95883 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 16 //  Total cost = 1049953.15 Elapsed time : 6 sec
# Testing // Epoch 16 //  Total cost = 451514.56  RMSE = 0.95703 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 17 //  Total cost = 1028497.32 Elapsed time : 6 sec
# Testing // Epoch 17 //  Total cost = 449668.22  RMSE = 0.95489 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 18 //  Total cost = 1006509.11 Elapsed time : 6 sec
# Testing // Epoch 18 //  Total cost = 447278.09  RMSE = 0.95244 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 19 //  Total cost = 985216.53 Elapsed time : 6 sec
# Testing // Epoch 19 //  Total cost = 446401.34  RMSE = 0.95132 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 20 //  Total cost = 963415.09 Elapsed time : 6 sec
# Testing // Epoch 20 //  Total cost = 442896.44  RMSE = 0.94761 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 21 //  Total cost = 942558.12 Elapsed time : 7 sec
# Testing // Epoch 21 //  Total cost = 441038.56  RMSE = 0.94557 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 22 //  Total cost = 920834.64 Elapsed time : 6 sec
# Testing // Epoch 22 //  Total cost = 438774.25  RMSE = 0.94306 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 23 //  Total cost = 901355.18 Elapsed time : 6 sec
# Testing // Epoch 23 //  Total cost = 437623.09  RMSE = 0.94178 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 24 //  Total cost = 879989.09 Elapsed time : 6 sec
# Testing // Epoch 24 //  Total cost = 433741.66  RMSE = 0.93746 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 25 //  Total cost = 859141.66 Elapsed time : 6 sec
# Testing // Epoch 25 //  Total cost = 432154.09  RMSE = 0.93566 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 26 //  Total cost = 838906.91 Elapsed time : 6 sec
# Testing // Epoch 26 //  Total cost = 428315.31  RMSE = 0.93138 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 27 //  Total cost = 817724.51 Elapsed time : 6 sec
# Testing // Epoch 27 //  Total cost = 426294.28  RMSE = 0.92911 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 28 //  Total cost = 797146.99 Elapsed time : 6 sec
# Testing // Epoch 28 //  Total cost = 424802.94  RMSE = 0.92739 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 29 //  Total cost = 776845.30 Elapsed time : 6 sec
# Testing // Epoch 29 //  Total cost = 420639.69  RMSE = 0.92268 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 30 //  Total cost = 757192.88 Elapsed time : 6 sec
# Testing // Epoch 30 //  Total cost = 417871.41  RMSE = 0.91951 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 31 //  Total cost = 736993.51 Elapsed time : 6 sec
# Testing // Epoch 31 //  Total cost = 416725.88  RMSE = 0.91814 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 32 //  Total cost = 717021.29 Elapsed time : 6 sec
# Testing // Epoch 32 //  Total cost = 412633.00  RMSE = 0.91351 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 33 //  Total cost = 697150.00 Elapsed time : 6 sec
# Testing // Epoch 33 //  Total cost = 409468.19  RMSE = 0.90984 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 34 //  Total cost = 677632.35 Elapsed time : 6 sec
# Testing // Epoch 34 //  Total cost = 406654.78  RMSE = 0.90660 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 35 //  Total cost = 658426.97 Elapsed time : 7 sec
# Testing // Epoch 35 //  Total cost = 404691.97  RMSE = 0.90428 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 36 //  Total cost = 640898.99 Elapsed time : 6 sec
# Testing // Epoch 36 //  Total cost = 403427.59  RMSE = 0.90273 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 37 //  Total cost = 624536.85 Elapsed time : 6 sec
# Testing // Epoch 37 //  Total cost = 401204.41  RMSE = 0.90015 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 38 //  Total cost = 607322.76 Elapsed time : 6 sec
# Testing // Epoch 38 //  Total cost = 397431.78  RMSE = 0.89574 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 39 //  Total cost = 591809.68 Elapsed time : 6 sec
# Testing // Epoch 39 //  Total cost = 395791.78  RMSE = 0.89378 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 40 //  Total cost = 576351.05 Elapsed time : 6 sec
# Testing // Epoch 40 //  Total cost = 395717.53  RMSE = 0.89359 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 41 //  Total cost = 562053.36 Elapsed time : 6 sec
# Testing // Epoch 41 //  Total cost = 392690.44  RMSE = 0.89007 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 42 //  Total cost = 547429.28 Elapsed time : 6 sec
# Testing // Epoch 42 //  Total cost = 389644.16  RMSE = 0.88646 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 43 //  Total cost = 533877.62 Elapsed time : 6 sec
# Testing // Epoch 43 //  Total cost = 387502.72  RMSE = 0.88392 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 44 //  Total cost = 519897.16 Elapsed time : 6 sec
# Testing // Epoch 44 //  Total cost = 386914.50  RMSE = 0.88316 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 45 //  Total cost = 507888.01 Elapsed time : 6 sec
# Testing // Epoch 45 //  Total cost = 385385.41  RMSE = 0.88127 Elapsed time : 3 sec
# ====================================================================================================
# Training // Epoch 46 //  Total cost = 496283.57 Elapsed time : 6 sec
# Testing // Epoch 46 //  Total cost = 385402.59  RMSE = 0.88128 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 47 //  Total cost = 486134.31 Elapsed time : 6 sec
# Testing // Epoch 47 //  Total cost = 383700.19  RMSE = 0.87920 Elapsed time : 3 sec
# ====================================================================================================
# Training // Epoch 48 //  Total cost = 476155.32 Elapsed time : 6 sec
# Testing // Epoch 48 //  Total cost = 381666.47  RMSE = 0.87673 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 49 //  Total cost = 465491.39 Elapsed time : 6 sec
# Testing // Epoch 49 //  Total cost = 380332.38  RMSE = 0.87514 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 50 //  Total cost = 454651.57 Elapsed time : 6 sec
# Testing // Epoch 50 //  Total cost = 378448.19  RMSE = 0.87289 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 51 //  Total cost = 445173.10 Elapsed time : 6 sec
# Testing // Epoch 51 //  Total cost = 377356.81  RMSE = 0.87154 Elapsed time : 3 sec
# ====================================================================================================
# Training // Epoch 52 //  Total cost = 436572.02 Elapsed time : 6 sec
# Testing // Epoch 52 //  Total cost = 374630.12  RMSE = 0.86824 Elapsed time : 3 sec
# ====================================================================================================
# Training // Epoch 53 //  Total cost = 428426.55 Elapsed time : 6 sec
# Testing // Epoch 53 //  Total cost = 373810.38  RMSE = 0.86720 Elapsed time : 3 sec
# ====================================================================================================
# Training // Epoch 54 //  Total cost = 420724.87 Elapsed time : 6 sec
# Testing // Epoch 54 //  Total cost = 373033.22  RMSE = 0.86630 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 55 //  Total cost = 413266.66 Elapsed time : 6 sec
# Testing // Epoch 55 //  Total cost = 371411.16  RMSE = 0.86428 Elapsed time : 3 sec
# ====================================================================================================
# Training // Epoch 56 //  Total cost = 407455.09 Elapsed time : 6 sec
# Testing // Epoch 56 //  Total cost = 370436.22  RMSE = 0.86312 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 57 //  Total cost = 400175.27 Elapsed time : 6 sec
# Testing // Epoch 57 //  Total cost = 369530.12  RMSE = 0.86190 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 58 //  Total cost = 393634.25 Elapsed time : 6 sec
# Testing // Epoch 58 //  Total cost = 368156.59  RMSE = 0.86027 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 59 //  Total cost = 387376.69 Elapsed time : 8 sec
# Testing // Epoch 59 //  Total cost = 369063.28  RMSE = 0.86128 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 60 //  Total cost = 381546.53 Elapsed time : 8 sec
# Testing // Epoch 60 //  Total cost = 366553.53  RMSE = 0.85829 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 61 //  Total cost = 376328.93 Elapsed time : 8 sec
# Testing // Epoch 61 //  Total cost = 365996.47  RMSE = 0.85752 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 62 //  Total cost = 371050.48 Elapsed time : 8 sec
# Testing // Epoch 62 //  Total cost = 365383.22  RMSE = 0.85677 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 63 //  Total cost = 365280.77 Elapsed time : 8 sec
# Testing // Epoch 63 //  Total cost = 364188.62  RMSE = 0.85531 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 64 //  Total cost = 359217.99 Elapsed time : 8 sec
# Testing // Epoch 64 //  Total cost = 363156.00  RMSE = 0.85405 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 65 //  Total cost = 354186.69 Elapsed time : 8 sec
# Testing // Epoch 65 //  Total cost = 363354.50  RMSE = 0.85426 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 66 //  Total cost = 349743.47 Elapsed time : 8 sec
# Testing // Epoch 66 //  Total cost = 361275.53  RMSE = 0.85163 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 67 //  Total cost = 345518.00 Elapsed time : 8 sec
# Testing // Epoch 67 //  Total cost = 361914.25  RMSE = 0.85248 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 68 //  Total cost = 341219.81 Elapsed time : 8 sec
# Testing // Epoch 68 //  Total cost = 359629.03  RMSE = 0.84957 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 69 //  Total cost = 338059.11 Elapsed time : 8 sec
# Testing // Epoch 69 //  Total cost = 360310.78  RMSE = 0.85043 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 70 //  Total cost = 334459.25 Elapsed time : 7 sec
# Testing // Epoch 70 //  Total cost = 358534.44  RMSE = 0.84816 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 71 //  Total cost = 330709.62 Elapsed time : 6 sec
# Testing // Epoch 71 //  Total cost = 356642.66  RMSE = 0.84579 Elapsed time : 3 sec
# ====================================================================================================
# Training // Epoch 72 //  Total cost = 326541.25 Elapsed time : 7 sec
# Testing // Epoch 72 //  Total cost = 356298.66  RMSE = 0.84542 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 73 //  Total cost = 323107.39 Elapsed time : 8 sec
# Testing // Epoch 73 //  Total cost = 356060.06  RMSE = 0.84510 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 74 //  Total cost = 319489.88 Elapsed time : 8 sec
# Testing // Epoch 74 //  Total cost = 355013.59  RMSE = 0.84378 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 75 //  Total cost = 315948.73 Elapsed time : 8 sec
# Testing // Epoch 75 //  Total cost = 355340.97  RMSE = 0.84419 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 76 //  Total cost = 313710.39 Elapsed time : 8 sec
# Testing // Epoch 76 //  Total cost = 353184.56  RMSE = 0.84141 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 77 //  Total cost = 310901.67 Elapsed time : 8 sec
# Testing // Epoch 77 //  Total cost = 351333.31  RMSE = 0.83906 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 78 //  Total cost = 307477.64 Elapsed time : 8 sec
# Testing // Epoch 78 //  Total cost = 353882.06  RMSE = 0.84231 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 79 //  Total cost = 304160.02 Elapsed time : 8 sec
# Testing // Epoch 79 //  Total cost = 351241.53  RMSE = 0.83899 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 80 //  Total cost = 301375.85 Elapsed time : 8 sec
# Testing // Epoch 80 //  Total cost = 352484.94  RMSE = 0.84061 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 81 //  Total cost = 298710.01 Elapsed time : 8 sec
# Testing // Epoch 81 //  Total cost = 349661.56  RMSE = 0.83699 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 82 //  Total cost = 296341.57 Elapsed time : 8 sec
# Testing // Epoch 82 //  Total cost = 350097.66  RMSE = 0.83746 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 83 //  Total cost = 293941.29 Elapsed time : 8 sec
# Testing // Epoch 83 //  Total cost = 348752.44  RMSE = 0.83579 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 84 //  Total cost = 291747.29 Elapsed time : 8 sec
# Testing // Epoch 84 //  Total cost = 350431.53  RMSE = 0.83799 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 85 //  Total cost = 289909.22 Elapsed time : 8 sec
# Testing // Epoch 85 //  Total cost = 348782.88  RMSE = 0.83585 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 86 //  Total cost = 288064.37 Elapsed time : 8 sec
# Testing // Epoch 86 //  Total cost = 348579.59  RMSE = 0.83546 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 87 //  Total cost = 286476.40 Elapsed time : 8 sec
# Testing // Epoch 87 //  Total cost = 348976.31  RMSE = 0.83611 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 88 //  Total cost = 284854.83 Elapsed time : 8 sec
# Testing // Epoch 88 //  Total cost = 346765.97  RMSE = 0.83325 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 89 //  Total cost = 282573.45 Elapsed time : 8 sec
# Testing // Epoch 89 //  Total cost = 346290.50  RMSE = 0.83269 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 90 //  Total cost = 280183.72 Elapsed time : 8 sec
# Testing // Epoch 90 //  Total cost = 346396.34  RMSE = 0.83281 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 91 //  Total cost = 278129.29 Elapsed time : 8 sec
# Testing // Epoch 91 //  Total cost = 345691.41  RMSE = 0.83196 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 92 //  Total cost = 276355.43 Elapsed time : 8 sec
# Testing // Epoch 92 //  Total cost = 345409.66  RMSE = 0.83154 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 93 //  Total cost = 274338.30 Elapsed time : 8 sec
# Testing // Epoch 93 //  Total cost = 344781.94  RMSE = 0.83073 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 94 //  Total cost = 272666.79 Elapsed time : 8 sec
# Testing // Epoch 94 //  Total cost = 344515.62  RMSE = 0.83046 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 95 //  Total cost = 270832.33 Elapsed time : 8 sec
# Testing // Epoch 95 //  Total cost = 344865.19  RMSE = 0.83089 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 96 //  Total cost = 269203.86 Elapsed time : 8 sec
# Testing // Epoch 96 //  Total cost = 343308.97  RMSE = 0.82896 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 97 //  Total cost = 268171.94 Elapsed time : 8 sec
# Testing // Epoch 97 //  Total cost = 343913.59  RMSE = 0.82966 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 98 //  Total cost = 267194.94 Elapsed time : 7 sec
# Testing // Epoch 98 //  Total cost = 344507.69  RMSE = 0.83043 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 99 //  Total cost = 266226.47 Elapsed time : 7 sec
# Testing // Epoch 99 //  Total cost = 342221.53  RMSE = 0.82739 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 100 //  Total cost = 264423.47 Elapsed time : 7 sec
# Testing // Epoch 100 //  Total cost = 341436.56  RMSE = 0.82646 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 101 //  Total cost = 262531.26 Elapsed time : 8 sec
# Testing // Epoch 101 //  Total cost = 339984.19  RMSE = 0.82466 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 102 //  Total cost = 260986.78 Elapsed time : 8 sec
# Testing // Epoch 102 //  Total cost = 341035.94  RMSE = 0.82596 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 103 //  Total cost = 259241.03 Elapsed time : 8 sec
# Testing // Epoch 103 //  Total cost = 340158.31  RMSE = 0.82482 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 104 //  Total cost = 257587.12 Elapsed time : 8 sec
# Testing // Epoch 104 //  Total cost = 340680.62  RMSE = 0.82556 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 105 //  Total cost = 256550.34 Elapsed time : 8 sec
# Testing // Epoch 105 //  Total cost = 337792.88  RMSE = 0.82182 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 106 //  Total cost = 256091.31 Elapsed time : 8 sec
# Testing // Epoch 106 //  Total cost = 339508.09  RMSE = 0.82414 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 107 //  Total cost = 255514.91 Elapsed time : 8 sec
# Testing // Epoch 107 //  Total cost = 338713.66  RMSE = 0.82296 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 108 //  Total cost = 254720.39 Elapsed time : 8 sec
# Testing // Epoch 108 //  Total cost = 338472.69  RMSE = 0.82258 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 109 //  Total cost = 254100.67 Elapsed time : 8 sec
# Testing // Epoch 109 //  Total cost = 338339.28  RMSE = 0.82236 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 110 //  Total cost = 252949.14 Elapsed time : 8 sec
# Testing // Epoch 110 //  Total cost = 337619.25  RMSE = 0.82160 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 111 //  Total cost = 251924.13 Elapsed time : 8 sec
# Testing // Epoch 111 //  Total cost = 339624.72  RMSE = 0.82423 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 112 //  Total cost = 252526.12 Elapsed time : 8 sec
# Testing // Epoch 112 //  Total cost = 337712.53  RMSE = 0.82160 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 113 //  Total cost = 252224.67 Elapsed time : 8 sec
# Testing // Epoch 113 //  Total cost = 338685.78  RMSE = 0.82305 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 114 //  Total cost = 250933.78 Elapsed time : 8 sec
# Testing // Epoch 114 //  Total cost = 335508.25  RMSE = 0.81866 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 115 //  Total cost = 249582.45 Elapsed time : 8 sec
# Testing // Epoch 115 //  Total cost = 336153.44  RMSE = 0.81968 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 116 //  Total cost = 247951.88 Elapsed time : 8 sec
# Testing // Epoch 116 //  Total cost = 335088.28  RMSE = 0.81808 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 117 //  Total cost = 246797.98 Elapsed time : 8 sec
# Testing // Epoch 117 //  Total cost = 334192.16  RMSE = 0.81705 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 118 //  Total cost = 245757.05 Elapsed time : 7 sec
# Testing // Epoch 118 //  Total cost = 334848.62  RMSE = 0.81763 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 119 //  Total cost = 246563.06 Elapsed time : 8 sec
# Testing // Epoch 119 //  Total cost = 334156.50  RMSE = 0.81697 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 120 //  Total cost = 245667.85 Elapsed time : 8 sec
# Testing // Epoch 120 //  Total cost = 333202.03  RMSE = 0.81586 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 121 //  Total cost = 244545.90 Elapsed time : 8 sec
# Testing // Epoch 121 //  Total cost = 334742.97  RMSE = 0.81774 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 122 //  Total cost = 243087.96 Elapsed time : 8 sec
# Testing // Epoch 122 //  Total cost = 332806.47  RMSE = 0.81541 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 123 //  Total cost = 241988.59 Elapsed time : 8 sec
# Testing // Epoch 123 //  Total cost = 332622.19  RMSE = 0.81501 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 124 //  Total cost = 241831.24 Elapsed time : 8 sec
# Testing // Epoch 124 //  Total cost = 333781.81  RMSE = 0.81664 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 125 //  Total cost = 241269.68 Elapsed time : 8 sec
# Testing // Epoch 125 //  Total cost = 336142.12  RMSE = 0.81978 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 126 //  Total cost = 242576.87 Elapsed time : 8 sec
# Testing // Epoch 126 //  Total cost = 333928.06  RMSE = 0.81682 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 127 //  Total cost = 242220.31 Elapsed time : 8 sec
# Testing // Epoch 127 //  Total cost = 332533.56  RMSE = 0.81485 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 128 //  Total cost = 241206.54 Elapsed time : 10 sec
# Testing // Epoch 128 //  Total cost = 332685.78  RMSE = 0.81510 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 129 //  Total cost = 240029.47 Elapsed time : 8 sec
# Testing // Epoch 129 //  Total cost = 331566.91  RMSE = 0.81373 Elapsed time : 5 sec
# ====================================================================================================
# Training // Epoch 130 //  Total cost = 239377.46 Elapsed time : 8 sec
# Testing // Epoch 130 //  Total cost = 330957.97  RMSE = 0.81272 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 131 //  Total cost = 238585.68 Elapsed time : 8 sec
# Testing // Epoch 131 //  Total cost = 332016.84  RMSE = 0.81444 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 132 //  Total cost = 237394.35 Elapsed time : 8 sec
# Testing // Epoch 132 //  Total cost = 333000.25  RMSE = 0.81558 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 133 //  Total cost = 236646.07 Elapsed time : 8 sec
# Testing // Epoch 133 //  Total cost = 331416.31  RMSE = 0.81360 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 134 //  Total cost = 235818.22 Elapsed time : 8 sec
# Testing // Epoch 134 //  Total cost = 330988.50  RMSE = 0.81304 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 135 //  Total cost = 235700.80 Elapsed time : 8 sec
# Testing // Epoch 135 //  Total cost = 333239.91  RMSE = 0.81609 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 136 //  Total cost = 236682.08 Elapsed time : 8 sec
# Testing // Epoch 136 //  Total cost = 331463.28  RMSE = 0.81367 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 137 //  Total cost = 236036.42 Elapsed time : 8 sec
# Testing // Epoch 137 //  Total cost = 330915.66  RMSE = 0.81288 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 138 //  Total cost = 235223.13 Elapsed time : 8 sec
# Testing // Epoch 138 //  Total cost = 329777.75  RMSE = 0.81145 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 139 //  Total cost = 234450.21 Elapsed time : 8 sec
# Testing // Epoch 139 //  Total cost = 329510.16  RMSE = 0.81104 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 140 //  Total cost = 233411.77 Elapsed time : 8 sec
# Testing // Epoch 140 //  Total cost = 330314.84  RMSE = 0.81227 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 141 //  Total cost = 233121.02 Elapsed time : 8 sec
# Testing // Epoch 141 //  Total cost = 329473.50  RMSE = 0.81101 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 142 //  Total cost = 233342.03 Elapsed time : 8 sec
# Testing // Epoch 142 //  Total cost = 329291.12  RMSE = 0.81078 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 143 //  Total cost = 232281.69 Elapsed time : 8 sec
# Testing // Epoch 143 //  Total cost = 329171.22  RMSE = 0.81076 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 144 //  Total cost = 232255.45 Elapsed time : 8 sec
# Testing // Epoch 144 //  Total cost = 329306.19  RMSE = 0.81084 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 145 //  Total cost = 231887.59 Elapsed time : 8 sec
# Testing // Epoch 145 //  Total cost = 328049.97  RMSE = 0.80922 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 146 //  Total cost = 231518.08 Elapsed time : 8 sec
# Testing // Epoch 146 //  Total cost = 328981.84  RMSE = 0.81049 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 147 //  Total cost = 231885.67 Elapsed time : 8 sec
# Testing // Epoch 147 //  Total cost = 330970.12  RMSE = 0.81314 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 148 //  Total cost = 231871.06 Elapsed time : 8 sec
# Testing // Epoch 148 //  Total cost = 330135.97  RMSE = 0.81199 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 149 //  Total cost = 231537.02 Elapsed time : 8 sec
# Testing // Epoch 149 //  Total cost = 327623.78  RMSE = 0.80861 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 150 //  Total cost = 230528.20 Elapsed time : 7 sec
# Testing // Epoch 150 //  Total cost = 326343.56  RMSE = 0.80685 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 151 //  Total cost = 229479.02 Elapsed time : 8 sec
# Testing // Epoch 151 //  Total cost = 325771.81  RMSE = 0.80591 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 152 //  Total cost = 230805.23 Elapsed time : 8 sec
# Testing // Epoch 152 //  Total cost = 326935.97  RMSE = 0.80766 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 153 //  Total cost = 230329.75 Elapsed time : 8 sec
# Testing // Epoch 153 //  Total cost = 326576.09  RMSE = 0.80726 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 154 //  Total cost = 228335.77 Elapsed time : 8 sec
# Testing // Epoch 154 //  Total cost = 326155.84  RMSE = 0.80658 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 155 //  Total cost = 226477.68 Elapsed time : 7 sec
# Testing // Epoch 155 //  Total cost = 326096.56  RMSE = 0.80680 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 156 //  Total cost = 225366.64 Elapsed time : 8 sec
# Testing // Epoch 156 //  Total cost = 326498.50  RMSE = 0.80727 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 157 //  Total cost = 224536.88 Elapsed time : 8 sec
# Testing // Epoch 157 //  Total cost = 325611.12  RMSE = 0.80605 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 158 //  Total cost = 224731.96 Elapsed time : 8 sec
# Testing // Epoch 158 //  Total cost = 326230.28  RMSE = 0.80683 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 159 //  Total cost = 225053.58 Elapsed time : 8 sec
# Testing // Epoch 159 //  Total cost = 326177.75  RMSE = 0.80692 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 160 //  Total cost = 224876.83 Elapsed time : 8 sec
# Testing // Epoch 160 //  Total cost = 326967.03  RMSE = 0.80804 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 161 //  Total cost = 225001.44 Elapsed time : 8 sec
# Testing // Epoch 161 //  Total cost = 325628.28  RMSE = 0.80609 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 162 //  Total cost = 224286.95 Elapsed time : 8 sec
# Testing // Epoch 162 //  Total cost = 325595.56  RMSE = 0.80612 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 163 //  Total cost = 224023.94 Elapsed time : 8 sec
# Testing // Epoch 163 //  Total cost = 326417.97  RMSE = 0.80735 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 164 //  Total cost = 223277.02 Elapsed time : 8 sec
# Testing // Epoch 164 //  Total cost = 325131.00  RMSE = 0.80545 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 165 //  Total cost = 223506.50 Elapsed time : 8 sec
# Testing // Epoch 165 //  Total cost = 325515.53  RMSE = 0.80612 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 166 //  Total cost = 223353.61 Elapsed time : 8 sec
# Testing // Epoch 166 //  Total cost = 325215.50  RMSE = 0.80552 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 167 //  Total cost = 223453.30 Elapsed time : 8 sec
# Testing // Epoch 167 //  Total cost = 326767.50  RMSE = 0.80782 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 168 //  Total cost = 223857.44 Elapsed time : 8 sec
# Testing // Epoch 168 //  Total cost = 324328.00  RMSE = 0.80437 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 169 //  Total cost = 223813.59 Elapsed time : 8 sec
# Testing // Epoch 169 //  Total cost = 325400.81  RMSE = 0.80591 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 170 //  Total cost = 223415.73 Elapsed time : 8 sec
# Testing // Epoch 170 //  Total cost = 324576.81  RMSE = 0.80476 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 171 //  Total cost = 223518.65 Elapsed time : 8 sec
# Testing // Epoch 171 //  Total cost = 323417.53  RMSE = 0.80313 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 172 //  Total cost = 223208.05 Elapsed time : 8 sec
# Testing // Epoch 172 //  Total cost = 323894.69  RMSE = 0.80355 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 173 //  Total cost = 223613.24 Elapsed time : 8 sec
# Testing // Epoch 173 //  Total cost = 323523.41  RMSE = 0.80321 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 174 //  Total cost = 223091.71 Elapsed time : 8 sec
# Testing // Epoch 174 //  Total cost = 323465.03  RMSE = 0.80330 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 175 //  Total cost = 222618.00 Elapsed time : 8 sec
# Testing // Epoch 175 //  Total cost = 324637.19  RMSE = 0.80496 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 176 //  Total cost = 222973.68 Elapsed time : 8 sec
# Testing // Epoch 176 //  Total cost = 323997.47  RMSE = 0.80379 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 177 //  Total cost = 222763.94 Elapsed time : 8 sec
# Testing // Epoch 177 //  Total cost = 322837.06  RMSE = 0.80251 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 178 //  Total cost = 221977.23 Elapsed time : 8 sec
# Testing // Epoch 178 //  Total cost = 323877.88  RMSE = 0.80389 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 179 //  Total cost = 220636.29 Elapsed time : 8 sec
# Testing // Epoch 179 //  Total cost = 323292.84  RMSE = 0.80312 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 180 //  Total cost = 220059.83 Elapsed time : 8 sec
# Testing // Epoch 180 //  Total cost = 322649.75  RMSE = 0.80221 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 181 //  Total cost = 219939.74 Elapsed time : 8 sec
# Testing // Epoch 181 //  Total cost = 322470.88  RMSE = 0.80210 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 182 //  Total cost = 220259.34 Elapsed time : 8 sec
# Testing // Epoch 182 //  Total cost = 323315.53  RMSE = 0.80315 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 183 //  Total cost = 220645.54 Elapsed time : 8 sec
# Testing // Epoch 183 //  Total cost = 322543.72  RMSE = 0.80200 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 184 //  Total cost = 221632.53 Elapsed time : 8 sec
# Testing // Epoch 184 //  Total cost = 324293.47  RMSE = 0.80449 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 185 //  Total cost = 221636.38 Elapsed time : 8 sec
# Testing // Epoch 185 //  Total cost = 323384.91  RMSE = 0.80328 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 186 //  Total cost = 221356.22 Elapsed time : 8 sec
# Testing // Epoch 186 //  Total cost = 323537.69  RMSE = 0.80339 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 187 //  Total cost = 221533.39 Elapsed time : 8 sec
# Testing // Epoch 187 //  Total cost = 322228.09  RMSE = 0.80169 Elapsed time : 4 sec
# ====================================================================================================
# ...
# ====================================================================================================
# Training // Epoch 438 //  Total cost = 199402.80 Elapsed time : 8 sec
# Testing // Epoch 438 //  Total cost = 312098.44  RMSE = 0.78912 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 439 //  Total cost = 199540.29 Elapsed time : 8 sec
# Testing // Epoch 439 //  Total cost = 311116.12  RMSE = 0.78784 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 440 //  Total cost = 198970.45 Elapsed time : 8 sec
# Testing // Epoch 440 //  Total cost = 311465.34  RMSE = 0.78829 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 441 //  Total cost = 198555.95 Elapsed time : 8 sec
# Testing // Epoch 441 //  Total cost = 311963.50  RMSE = 0.78905 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 442 //  Total cost = 198575.24 Elapsed time : 8 sec
# Testing // Epoch 442 //  Total cost = 310233.53  RMSE = 0.78666 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 443 //  Total cost = 198562.26 Elapsed time : 8 sec
# Testing // Epoch 443 //  Total cost = 311950.25  RMSE = 0.78903 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 444 //  Total cost = 198494.74 Elapsed time : 8 sec
# Testing // Epoch 444 //  Total cost = 311784.91  RMSE = 0.78884 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 445 //  Total cost = 198781.76 Elapsed time : 8 sec
# Testing // Epoch 445 //  Total cost = 310465.69  RMSE = 0.78674 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 446 //  Total cost = 199709.75 Elapsed time : 8 sec
# Testing // Epoch 446 //  Total cost = 312913.38  RMSE = 0.79040 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 447 //  Total cost = 200791.73 Elapsed time : 8 sec
# Testing // Epoch 447 //  Total cost = 310172.25  RMSE = 0.78649 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 448 //  Total cost = 200707.86 Elapsed time : 8 sec
# Testing // Epoch 448 //  Total cost = 310564.66  RMSE = 0.78687 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 449 //  Total cost = 200279.94 Elapsed time : 8 sec
# Testing // Epoch 449 //  Total cost = 310553.78  RMSE = 0.78693 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 450 //  Total cost = 199071.14 Elapsed time : 8 sec
# Testing // Epoch 450 //  Total cost = 311368.03  RMSE = 0.78825 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 451 //  Total cost = 197747.40 Elapsed time : 8 sec
# Testing // Epoch 451 //  Total cost = 310943.78  RMSE = 0.78757 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 452 //  Total cost = 197210.09 Elapsed time : 8 sec
# Testing // Epoch 452 //  Total cost = 311136.19  RMSE = 0.78796 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 453 //  Total cost = 196885.52 Elapsed time : 8 sec
# Testing // Epoch 453 //  Total cost = 310390.00  RMSE = 0.78682 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 454 //  Total cost = 196691.80 Elapsed time : 8 sec
# Testing // Epoch 454 //  Total cost = 310596.06  RMSE = 0.78722 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 455 //  Total cost = 196593.58 Elapsed time : 8 sec
# Testing // Epoch 455 //  Total cost = 312215.88  RMSE = 0.78948 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 456 //  Total cost = 197004.60 Elapsed time : 8 sec
# Testing // Epoch 456 //  Total cost = 310371.97  RMSE = 0.78689 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 457 //  Total cost = 197196.46 Elapsed time : 8 sec
# Testing // Epoch 457 //  Total cost = 310928.31  RMSE = 0.78765 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 458 //  Total cost = 197429.49 Elapsed time : 8 sec
# Testing // Epoch 458 //  Total cost = 310595.69  RMSE = 0.78717 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 459 //  Total cost = 197668.15 Elapsed time : 8 sec
# Testing // Epoch 459 //  Total cost = 312410.28  RMSE = 0.78985 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 460 //  Total cost = 198301.29 Elapsed time : 8 sec
# Testing // Epoch 460 //  Total cost = 310986.38  RMSE = 0.78778 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 461 //  Total cost = 198391.68 Elapsed time : 8 sec
# Testing // Epoch 461 //  Total cost = 310173.12  RMSE = 0.78645 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 462 //  Total cost = 198149.78 Elapsed time : 8 sec
# Testing // Epoch 462 //  Total cost = 311424.75  RMSE = 0.78835 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 463 //  Total cost = 198008.04 Elapsed time : 8 sec
# Testing // Epoch 463 //  Total cost = 311524.09  RMSE = 0.78845 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 464 //  Total cost = 198559.68 Elapsed time : 8 sec
# Testing // Epoch 464 //  Total cost = 310130.47  RMSE = 0.78641 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 465 //  Total cost = 198337.81 Elapsed time : 8 sec
# Testing // Epoch 465 //  Total cost = 310109.44  RMSE = 0.78629 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 466 //  Total cost = 198804.30 Elapsed time : 8 sec
# Testing // Epoch 466 //  Total cost = 310897.97  RMSE = 0.78753 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 467 //  Total cost = 198517.45 Elapsed time : 8 sec
# Testing // Epoch 467 //  Total cost = 310431.78  RMSE = 0.78698 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 468 //  Total cost = 197769.96 Elapsed time : 8 sec
# Testing // Epoch 468 //  Total cost = 310550.28  RMSE = 0.78706 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 469 //  Total cost = 197040.64 Elapsed time : 8 sec
# Testing // Epoch 469 //  Total cost = 310107.62  RMSE = 0.78651 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 470 //  Total cost = 197082.36 Elapsed time : 8 sec
# Testing // Epoch 470 //  Total cost = 309991.16  RMSE = 0.78624 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 471 //  Total cost = 197159.45 Elapsed time : 8 sec
# Testing // Epoch 471 //  Total cost = 310434.88  RMSE = 0.78697 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 472 //  Total cost = 197312.67 Elapsed time : 8 sec
# Testing // Epoch 472 //  Total cost = 310083.47  RMSE = 0.78654 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 473 //  Total cost = 197345.72 Elapsed time : 8 sec
# Testing // Epoch 473 //  Total cost = 310609.88  RMSE = 0.78725 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 474 //  Total cost = 197635.95 Elapsed time : 8 sec
# Testing // Epoch 474 //  Total cost = 309453.50  RMSE = 0.78537 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 475 //  Total cost = 198549.66 Elapsed time : 8 sec
# Testing // Epoch 475 //  Total cost = 310378.66  RMSE = 0.78693 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 476 //  Total cost = 199017.07 Elapsed time : 8 sec
# Testing // Epoch 476 //  Total cost = 311999.47  RMSE = 0.78916 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 477 //  Total cost = 198908.16 Elapsed time : 8 sec
# Testing // Epoch 477 //  Total cost = 311096.47  RMSE = 0.78782 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 478 //  Total cost = 198630.89 Elapsed time : 8 sec
# Testing // Epoch 478 //  Total cost = 311842.84  RMSE = 0.78902 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 479 //  Total cost = 198372.77 Elapsed time : 8 sec
# Testing // Epoch 479 //  Total cost = 310869.78  RMSE = 0.78759 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 480 //  Total cost = 198478.72 Elapsed time : 8 sec
# Testing // Epoch 480 //  Total cost = 309820.62  RMSE = 0.78593 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 481 //  Total cost = 198834.52 Elapsed time : 8 sec
# Testing // Epoch 481 //  Total cost = 310500.84  RMSE = 0.78701 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 482 //  Total cost = 198342.50 Elapsed time : 8 sec
# Testing // Epoch 482 //  Total cost = 310870.94  RMSE = 0.78768 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 483 //  Total cost = 197394.27 Elapsed time : 8 sec
# Testing // Epoch 483 //  Total cost = 310379.16  RMSE = 0.78682 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 484 //  Total cost = 197059.94 Elapsed time : 8 sec
# Testing // Epoch 484 //  Total cost = 310266.00  RMSE = 0.78673 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 485 //  Total cost = 196912.90 Elapsed time : 8 sec
# Testing // Epoch 485 //  Total cost = 309575.62  RMSE = 0.78578 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 486 //  Total cost = 196890.51 Elapsed time : 8 sec
# Testing // Epoch 486 //  Total cost = 309954.00  RMSE = 0.78633 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 487 //  Total cost = 196982.38 Elapsed time : 8 sec
# Testing // Epoch 487 //  Total cost = 310112.75  RMSE = 0.78650 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 488 //  Total cost = 197037.92 Elapsed time : 8 sec
# Testing // Epoch 488 //  Total cost = 309345.88  RMSE = 0.78549 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 489 //  Total cost = 197387.55 Elapsed time : 8 sec
# Testing // Epoch 489 //  Total cost = 311514.75  RMSE = 0.78851 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 490 //  Total cost = 197674.76 Elapsed time : 8 sec
# Testing // Epoch 490 //  Total cost = 311722.22  RMSE = 0.78894 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 491 //  Total cost = 198355.73 Elapsed time : 8 sec
# Testing // Epoch 491 //  Total cost = 310287.62  RMSE = 0.78677 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 492 //  Total cost = 198201.46 Elapsed time : 8 sec
# Testing // Epoch 492 //  Total cost = 310176.03  RMSE = 0.78663 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 493 //  Total cost = 197987.33 Elapsed time : 8 sec
# Testing // Epoch 493 //  Total cost = 310699.19  RMSE = 0.78727 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 494 //  Total cost = 197521.11 Elapsed time : 8 sec
# Testing // Epoch 494 //  Total cost = 310599.41  RMSE = 0.78727 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 495 //  Total cost = 197221.37 Elapsed time : 8 sec
# Testing // Epoch 495 //  Total cost = 310717.03  RMSE = 0.78728 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 496 //  Total cost = 197249.64 Elapsed time : 8 sec
# Testing // Epoch 496 //  Total cost = 309751.78  RMSE = 0.78595 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 497 //  Total cost = 197201.19 Elapsed time : 8 sec
# Testing // Epoch 497 //  Total cost = 309675.41  RMSE = 0.78594 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 498 //  Total cost = 197266.66 Elapsed time : 8 sec
# Testing // Epoch 498 //  Total cost = 310352.84  RMSE = 0.78699 Elapsed time : 4 sec
# ====================================================================================================
# Training // Epoch 499 //  Total cost = 197424.14 Elapsed time : 8 sec
# Testing // Epoch 499 //  Total cost = 309544.44  RMSE = 0.78575 Elapsed time : 4 sec
# ====================================================================================================
